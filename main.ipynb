# %% [markdown]
# ### Importações

# %%
import time
from selenium import webdriver
import csv
import requests
from bs4 import BeautifulSoup
from datetime import datetime
from datetime import timedelta
import sqlite3
import csv

# %% [markdown]
# ### Classe que realiza requisições para o portal do g1

# %%
 class G1PageScrapper:
    
    mainUrl = "https://g1.globo.com/"
    searchPath = "busca/?q="
    
    
    def __init__(self):
        self.data = []
    
    def access(self, link):
        ret = BeautifulSoup(requests.get(link).content, 'html.parser')
        return ret
    
    def mountSearchUrl(self, expression, page=1):
        words = expression.split(" ")
        
        queryParamValue =  ""
        
        for word in words:
            queryParamValue += '+' + word 
        
        queryParamValue = queryParamValue.replace('+','',1)    
        
        return self.mainUrl+self.searchPath+queryParamValue+"&page="+str(page)
    
    def searchDepth(self, expression, page=1, pageDepth=1):
        
        ret = []
        i=0
        
        while i< pageDepth:
            print(self.mountSearchUrl(expression, page+i))
            ret.append(G1SearchReader(self.access(self.mountSearchUrl(expression, page+i))));
            i+=1
        return ret
    
    def search(self, expression, page=1):
               
        result = self.searchDepth(expression, page, 1)
               
        return result[0] if len(result) != 0 else  null
    
    def readNews(self,url):
        return G1NewsReader(self.access(url))

# %%
class G1SearchReader:
    
    def __init__(self, bsObject):
        self.content = bsObject
    
    def getContent(self):
        return self.content
    
    def listNewsCardList(self):
        cardsList = self.content.find_all(class_="widget widget--card widget--info") 
        
        ret = []
        
        for card in cardsList:
            
            newsCard = G1NewsCard(card)
            newsCard.title = card.find_all("div", class_="widget--info__title product-color ")[0].getText()
            newsCard.link = card.find_all("div", class_="widget--info__text-container")[0].find_all("a")[0].get("href").replace("//","http://",1)
            dateStr = card.find_all("div", class_="widget--info__meta")[0].getText()
            
            newsDate = None
            
            if dateStr.find("dia") != -1:
                parts = dateStr.split(" ")
                newsDate = datetime.now() - timedelta(days=int(parts[1])) 
            elif dateStr.find("minuto") != -1 or dateStr.find("segundo") != -1 or dateStr.find("instante") != -1 or dateStr.find("hora") != -1 :
                newsDate = datetime.now()
            else: 
                parts = dateStr.split(" ")
                newsDate = datetime.strptime(parts[0], "%d/%m/%Y")
            
            newsCard.date = newsDate
                        
            ret.append(newsCard)
        
        return ret

# %%
class G1NewsReader:
    
    def __init__(self, bsObject):
        self.content = bsObject
        
        print(bsObject)
        print(bsObject.find_all("main", class_="mc-body theme")) 
        print(bsObject.find_all("div", class_="glb-materia") )
        print(bsObject.find_all("div", class_="playkit-video-info__container_info playkit-video-stage__area-video-info-container") )
               
        
    
    def getContent(self):
        return self.content

# %%
class G1NewsCard:
    
    def __init__(self, bsObject):
        self.content = bsObject       
    
    def getContent(self):
        return self.content

# %% [markdown]
# ### Programa principal

# %%
webPageScrapper = G1PageScrapper()

searchReaderArray = webPageScrapper.searchDepth("jair bolsonaro", pageDepth=40)

allNewsArray = []

now = datetime.now()

for reader in searchReaderArray:
    allNewsArray += reader.listNewsCardList()
    for news in reader.listNewsCardList():
        print(news.title)
    
print(len(allNewsArray))
# Out:
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=1
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=2
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=3
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=4
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=5
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=6
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=7
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=8
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=9
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=10
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=11
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=12
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=13
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=14
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=15
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=16
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=17
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=18
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=19
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=20
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=21
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=22
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=23
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=24
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=25
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=26
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=27
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=28
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=29
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=30
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=31
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=32
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=33
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=34
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=35
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=36
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=37
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=38
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=39
# https://g1.globo.com/busca/?q=jair+bolsonaro&page=40
#
#         Jair Bolsonaro faz campanha em Presidente Prudente
#
#
#         Jair Bolsonaro faz campanha em Presidente Prudente
#
#
#         Jair Bolsonaro faz campanha em Presidente Prudente
#
#
#         Jair Bolsonaro (PSL) faz campanha no interior de São Paulo
#
#
#         Veja a agenda de campanha do candidato à presidência pelo PSL, Jair Bolsonaro
#
#
#         Jair Bolsonaro (PSL) acompanhou enterro de policial militar no Rio na terça (21)
#
#
#         Candidato Jair Bolsonaro fala da morte do militar no Alemão
#
#
#         Jair Bolsonaro em cerimônia de entrega de espadins na Academia Militar das Agulhas Negras
#
#
#         Em SP, Ibope aponta para presidente: Lula, 23%; Jair Bolsonaro, 19%; Geraldo Alckmin, 13%
#
#
#         O candidato do PSL à Presidência da República, Jair Bolsonaro, durante cerimônia em SP
#
#
#         O candidato do PSL à Presidência da República Jair Bolsonaro posou para fotografias em SP
#
#
#         Secretária parlamentar do candidato Jair Bolsonaro pede demissão
#
#
#         STF deixou 'em aberto' se réu pode assumir Presidência, afirma Marco Aurélio Mello
#
#
#         O deputado Jair Bolsonaro dá entrevista na Câmara sobre a demissão de servidora
#
#
#         Veja o que é #FATO ou #FAKE na entrevista de Jair Bolsonaro no Roda Viva
#
#
#         Veja o que é #FATO ou #FAKE na entrevista de Jair Bolsonaro para a GloboNews
#
#
#         General Hamilton Mourão (PRTB) será vice de Jair Bolsonaro (PSL)
#
#
#         Termina nesta quarta (22) o prazo para impugnações às candidaturas à presidência
#
#
#         Fato ou Fake analisa entrevista do candidato à presidência Jair Bolsonaro (PSL)
#
#
#         Em SP, Ibope aponta para presidente: Lula, 23%; Jair Bolsonaro, 18%; Geraldo Alckmin, 15%
#
#
#         PRTB anuncia apoio a Jair Bolsonaro, candidato do PSL à presidência
#
#
#         PRTB decide apoiar candidatura de Jair Bolsonaro à presidência da República
#
#
#         Jair Bolsonaro diz que, se eleito, pode privatizar Petrobras 'se não tiver solução'
#
#
#         Janaína Paschoal nega convite para ser vice na chapa de Jair Bolsonaro
#
#
#         Jair Bolsonaro, candidato do PSL à presidência, participa da Central das Eleições
#
#
#         FN2 - Edição de Quarta-feira, 22/08/2018
#
#
#         PSL oficializa candidatura de Jair Bolsonaro à Presidência da República
#
#
#         PSL oficializa candidatura de Jair Bolsonaro à presidência
#
#
#         PSL oficializa candidatura de Jair Bolsonaro à presidência
#
#
#         PSL oficializa candidatura de Jair Bolsonaro à Presidência
#
#
#         Candidatura de Jair Bolsonaro à Presidência é oficializada pelo PSL
#
#
#         PSL oficializa candidatura de Jair Bolsonaro à Presidência
#
#
#         Jair Bolsonaro é confirmado candidato à presidência pelo PSL
#
#
#         Bolsonaro diz que 'bandidagem vai morrer' em seu governo porque União não repassará recursos para direitos humanos
#
#
#         Em SP, Ibope aponta para presidente: Lula, 24%; Jair Bolsonaro, 17%; Geraldo Alckmin, 13%
#
#
#         Jair Bolsonaro é oficializado candidato à Presidência da República pelo PSL
#
#
#         PSL oficializa a candidatura de Jair Bolsonaro à presidência da República
#
#
#         Jair Bolsonaro enfrenta dificuldades com alianças na corrida presidencial
#
#
#         PSL oficializa candidatura de Jair Bolsonaro à Presidência, mas adia definição de vice
#
#
#         PSL oficializa a candidatura do deputado Jair Bolsonaro à presidência da República
#
#
#         General Augusto Heleno não será vice de Jair Bolsonaro na corrida presidencial
#
#
#         Veja o que é #FATO ou #FAKE nas falas dos presidenciáveis no debate da RedeTV
#
#
#         Alckmin diz que Bolsonaro 'perde para qualquer um' no segundo turno
#
#
#         Pesquisa Datafolha em DF, MG, RJ, PE e SP: Lula tem pior desempenho no DF; Bolsonaro, em Pernambuco
#
#
#         Oito presidenciáveis discutem propostas de governo no segundo debate da campanha eleitoral de 2018
#
#
#         A disputa pelo eleitor mais pobre
#
#
#         Pesquisa Datafolha: Lula, 39%; Bolsonaro, 19%; Marina, 8%; Alckmin, 6%; Ciro, 5%
#
#
#         Bolsonaro diz que vai usar Revalida para 'expulsar' médicos cubanos do Brasil
#
#
#         Marco Aurélio libera para julgamento denúncia de racismo contra Bolsonaro
#
#
#         Jair Bolsonaro pede ao STF para ser absolvido da acusação de racismo
#
#
#         Pesquisa Datafolha de 22 de agosto para presidente por sexo, idade, escolaridade, renda, região e religião
#
#
#         Veja o que é #FATO ou #FAKE nas entrevistas dos presidenciáveis para a GloboNews
#
#
#         Pesquisa Ibope: Lula, 37%; Bolsonaro, 18%; Marina, 6%; Ciro, 5%; Alckmin, 5%
#
#
#         Bolsonaro resiste incólume
#
#
#         Elevada rejeição de Bolsonaro impõe limite para o candidato no segundo turno
#
#
#         TSE aprova registro de candidaturas de Cabo Daciolo, Guilherme Boulos, João Amoêdo e Marina Silva
#
#
#         Bolsonaro se firma como anti-Lula, mas patina nas projeções de segundo turno
#
#
#         Pesquisa Datafolha: 1 em cada 5 brasileiros compartilha notícias de política em Facebook e WhatsApp
#
#
#         TSE recebe pedido para impugnar candidatura de Bolsonaro
#
#
#         Navios portugueses e brasileiros fizeram mais de 9 mil viagens com escravos da África para o Brasil
#
#
#         ‘Bolsonaro entrou numa agenda negativa’, diz Camarotti
#
#
#         Bolsonaro vai a enterro de militar morto em operação no Complexo do Alemão
#
#
#         PGR denuncia Jair Bolsonaro por racismo
#
#
#         Veja o que é #FATO ou #FAKE nas falas dos presidenciáveis no debate da Band
#
#
#         Veja a agenda de campanha de candidatos à Presidência
#
#
#         Veja o que é #FATO ou #FAKE na entrevista de Ciro Gomes para a GloboNews
#
#
#         Procuradora-geral da República entra com ação de impugnação contra candidatura de Lula
#
#
#         Veja o que é #FATO ou #FAKE na entrevista de Alvaro Dias para a GloboNews
#
#
#         TSE apresenta previsão do tempo de propaganda no rádio e na TV para cada candidato à Presidência
#
#
#         Primeiro debate da eleição 2018 reúne 8 presidenciáveis por mais de 3 horas na TV
#
#
#         Jair Bolsonaro é denunciado ao Supremo por crime de racismo
#
#
#         PGR denuncia Jair Bolsonaro por racismo
#
#
#         Assessora de Bolsonaro se demite ao ser flagrada vendendo açaí na praia
#
#
#         Veja o que é #FATO ou #FAKE na entrevista de Marina Silva para a GloboNews
#
#
#         Veja o que é #FATO ou #FAKE na entrevista de Geraldo Alckmin para a GloboNews
#
#
#         Ministro Celso de Mello manda arquivar queixa de Jean Wyllys contra Jair Bolsonaro
#
#
#         Demitida a secretária parlamentar que vendia açaí no Rio de Janeiro
#
#
#         Pesquisa Ibope de 20 de agosto para presidente por sexo, idade, escolaridade, renda, região, religião e raça
#
#
#         PGR oferece denúncia contra Jair Bolsonaro ao STF por racismo.
#
#
#         Jair Bolsonaro passa mal e é atendido em Hospital Central do Exército no Rio
#
#
#         Em São Paulo, Ibope aponta: Lula, 20%; Geraldo Alckmin e Jair Bolsonaro, 14%
#
#
#         'Mudança' é o tema mais comum em jingles de presidenciáveis
#
#
#         Procuradoria-Geral da República denunciou o deputado federal Jair Bolsonaro por racismo
#
#
#         Datafolha divulga primeira pesquisa para Presidência após registro no TSE
#
#
#         38% dos candidatos declaram patrimônio zero nas eleições deste ano; 10% são milionários
#
#
#         Meirelles propõe Imposto de Renda maior para quem ganha mais e criação de tributo sobre dividendos
#
#
#         Alckmin diz que se eleito reduzirá número de ministérios de 29 para pelo menos 21
#
#
#         Pesquisa Datafolha de 22 de agosto: interesse dos brasileiros pelas eleições
#
#
#         Bolsonaro diz que vai tirar Brasil da ONU se for eleito presidente
#
#
#         Deputado Jair Bolsonaro anuncia filiação ao PSL
#         Procuradoria aponta campanha antecipada e pede retirada de outdoors de Jair Bolsonaro em Taubaté
#
#
#         Ministra Rosa Weber recebe denúncia da PGR contra Jair Bolsonaro (PSL-RJ)
#
#
#         Bolsonaro chama de 'analfabeto' quem critica seu plano de governo
#
#
#         No último dia do prazo, algumas chapas foram definidas com os vices
#
#
#         Ciro diz que 'só quem tem horror a povo' fica contra proposta de refinanciar dívidas de brasileiros no SPC
#
#
#         Vice de Bolsonaro faz declaração polêmica em evento no RS
#
#
#         Mourão diz que foi mal interpretado em declaração no RS
#
#
#         A falsa esperança em Marina
#
#
#         Governo manda 120 militares para Roraima. FH diz que soluções de Bolsonaro assustam. Jornais de segunda (20)
#
#
#         Veja a agenda de campanha dos candidatos à Presidência na terça (21)
#
#
#         PRTB oficializa apoio a Bolsonaro à presidência e general Mourão como candidato a vice
#
#
#         Para cientista político, pesquisa Ibope mostra que início da campanha não reduziu imprevisibilidade
#
#
#         Boulos diz que se eleito concederá perdão de pena ao ex-presidente Lula
#
#
#         ‘Declaração de Mourão fornece munição para adversários de Bolsonaro’, diz Valdo
#
#
#         Jair Bolsonaro participa de ato simbólico de filiação ao PSL; partido vai lançá-lo pré-candidato à Presidência
#
#
#         Brasil herdou 'malandragem' do africano, diz Mourão, vice na chapa de Bolsonaro
#
#
#         Bolsonaro (PSL) escolhe General Mourão como vice
#
#
#         Bolsonaro atribui decisões econômicas a Paulo Guedes
#
#
#         Em programa de governo, Bolsonaro diz que vai criar Ministério da Economia
#
#
#         Bolsonaro contesta no TSE o registro da candidatura do ex-presidente Lula
#
#
#         Planos de Bolsonaro decepcionam
#
#
#         Vice de Bolsonaro diz que foi mal interpretado e que não é racista
#
#
#         Incerteza segue como marca da eleição e eleva preocupação no mercado
#
#
#         ‘Quanto mais Mourão explica, pior fica’, diz Merval
#
#
#         Marina confronta Bolsonaro em segundo debate; Recursos sobre Lula concentrados em Barroso. Jornais de sábado (18)
#
#
#         PT, PRTB e PDT anunciam nomes dos vices nas chapas à presidência da república
#
#
#         Vendedora de açaí deixa cargo de secretária parlamentar de Bolsonaro
#
#
#         Teto de gastos somente será sustentável com reforma da Previdência, diz Guardia
#
#
#         Bolsonaro propõe eliminar 'fraudes' para aumentar valor do Bolsa Família
#
#
#         Deputado Jair Bolsonaro (PSC-RJ) anuncia voto
#
#
#         PSL faz convenção nacional eleitoral no Rio de Janeiro
#
#
#         Lideranças do PSL no AC pedem desligamento do partido após deputado Jair Bolsonaro anunciar filiação
#
#
#         'Sou especialista em passar em frestas', diz Marina sobre o pouco tempo que terá na propaganda eleitoral
#
#
#         Veja a agenda de campanha dos candidatos à Presidência
#
#
#         Parentes de cabo e soldado mortos em operação falam da dedicação à carreira militar
#
#
#         Ibope divulga primeira pesquisa para Presidência após registro no TSE
#
#
#         Jair Bolsonaro é hostilizado com ovada durante visita a Ribeirão Preto
#
#
#         Após declaração polêmica, vice de Bolsonaro se autodeclara indígena ao TSE
#
#
#         Marina diz que se eleita viabilizará 'inserção' das mulheres no processo produtivo
#
#
#         Deputado Jair Bolsonaro (PSC-RJ) anuncia voto
#
#
#         Bolsonaro diz que funcionária apontada como 'fantasma' pediu demissão por ter sido mencionada em debate na TV
#
#
#         Alianças nos estados contrariam 12 das 13 chapas presidenciais
#
#
#         Seis pré-candidatos a presidente da República apresentam propostas em evento da indústria em Brasília
#
#
#         Veja a programação de agosto da GloboNews
#
#
#         Jair Bolsonaro é condenado a pagar R$ 50 mil por danos morais a comunidades quilombolas e população negra
#
#
#         Vereadores de Araguaína aprovam moção de aplausos para deputado Jair Bolsonaro
#
#
#         Fato ou Fake analisa entrevista do candidato à presidência Jair Bolsonaro (PSL)
#
#
#         Janaína Paschoal nega convite para ser vice na chapa de Jair Bolsonaro
#
#
#         General Augusto Heleno não será vice de Jair Bolsonaro na corrida presidencial
#
#
#         Jair Bolsonaro participa de ato simbólico de filiação ao PSL; partido vai lançá-lo pré-candidato à Presidência
#
#
#         Conselho de Ética da Câmara decide abrir processo contra o deputado Jair Bolsonaro
#
#
#         Manifestantes realizam ato na Praia de iracema contra deputado estual Jair Bolsonaro
#
#
#         Manifestantes fazem ato contra cassação do mandato do deputado estadual Jair Bolsonaro.
#
#
#         Instituto Vladimir Herzog divulga nota de repúdio a discurso de Jair Bolsonaro
#
#
#         Conselho de Ética da Câmara abre processo disciplinar contra Jair Bolsonaro
#
#
#         Jair Bolsonaro chuta boneco de Lula durante manifestação em Copacabana, no Rio
#
#
#         OAB-RJ protocola pedido de cassação do mandato do deputado Jair Bolsonaro
#
#
#         Dilma diz que fala do deputado Jair Bolsonaro sobre tortura foi 'lamentável'
#
#
#         Jair Bolsonaro (PP-RJ) diz que precisamos de um presidente com autoridade e altivez
#
#
#         Jair Bolsonaro (PP-RJ) diz que crise brasileira é 'nos três poderes'
#
#
#         Lula tem 30%, Bolsonaro, 17%, Marina, 10%, aponta pesquisa Datafolha para 2018
#
#
#         Hackers apagam clipe de Pabllo Vittar e colocam foto do deputado Jair Bolsonaro na página
#
#
#         PSL confirma candidatura de Cirilo Fernandes ao governo do Amapá
#
#
#         Lula tem 31%, Bolsonaro, 15%, Marina, 10%, aponta pesquisa Datafolha para 2018
#
#
#         Entidades repudiam fala de general vice de Bolsonaro sobre negros e índios
#
#
#         Veja o patrimônio que os candidatos a presidente declararam ao TSE
#
#
#         Lula tem 33%, Bolsonaro, 15%, Marina, 7%, e Ciro, 4%, aponta pesquisa Ibope
#
#
#         Bolsonaro anuncia general Hamilton Mourão como vice
#
#
#         Janaína Paschoal recusa convite para ser vice de Bolsonaro
#
#
#         Aliados de Haddad criticam 'fogo amigo' do PT e dizem que Bolsonaro é assunto para Geraldo Alckmin
#
#
#         Jair Bolsonaro discursa na Câmara
#
#
#         É #FAKE mensagem que diz que professor expulsou aluna da sala de aula por usar camiseta pró-Bolsonaro
#
#
#         TSE recebe pedidos de registro de 13 candidatos à Presidência da República
#
#
#         Cacau Menezes entrevista Jair Bolsonaro ao vivo no Jornal do Almoço
#
#
#         Vice de Bolsonaro afirma que Brasil herdou 'indolência' do índio e 'malandragem' do africano durante evento no RS
#
#
#         Ciro diz que 'só quem tem horror a povo' fica contra proposta de refinanciar dívidas de brasileiros no SPC
#
#
#         'Quem precisa de solução é o povo brasileiro', diz Jair Bolsonaro (PP-RJ)
#
#
#         Ministra Rosa Weber recebe denúncia da PGR contra Jair Bolsonaro (PSL-RJ)
#
#
#         Hackers apagam clipe de Pabllo Vittar e colocam foto do deputado Jair Bolsonaro na página
#
#
#         Boulos diz que se eleito concederá perdão de pena ao ex-presidente Lula
#
#
#         Bolsonaro diz que vai tirar Brasil da ONU se for eleito presidente
#
#
#         Jair Bolsonaro (PP-RJ) diz que presidente da Casa precisa entregá-la ao povo brasileiro
#
#
#         G1 em 1 Minuto: Conselho de Ética da Câmara abre processo contra deputado Jair Bolsonaro
#
#
#         Jair Bolsonaro diz que governo usaria hipotético ataque terrorista para não deixar o poder
#
#
#         Visita do deputado federal Jair Bolsonaro à Assembleia Legislativa do RS gera confusão
#
#
#         Jair Bolsonaro vira réu no STF por incitação ao estupro e injúria contra Maria do Rosário
#
#
#         38% dos candidatos declaram patrimônio zero nas eleições deste ano; 10% são milionários
#
#
#         Bolsonaro contesta no TSE o registro da candidatura do ex-presidente Lula
#
#
#         Bolsonaro vai a enterro de militar morto em operação no Complexo do Alemão
#
#
#         Marina confronta Bolsonaro em segundo debate; Recursos sobre Lula concentrados em Barroso. Jornais de sábado (18)
#         Jair Bolsonaro (PP-RJ) diz que precisamos de um presidente com autoridade e altivez
#
#
#         Jair Bolsonaro (PP-RJ) diz que crise brasileira é 'nos três poderes'
#
#
#         Divulgada pesquisa CNI-Ibope com a intenção de voto para a Presidência da República
#
#
#         Jair Bolsonaro interrompe discurso de Ana Cláudia Macedo
#
#
#         Instituto Vladimir Herzog pede que deputados expulsem Jair Bolsonaro
#
#
#         STF aceita denúncia contra Jair Bolsonaro por incitar estupro
#
#
#         Rosa Weber decidirá se escolhe um único relator para registro e impugnações da candidatura de Lula
#
#
#         Jair Bolsonaro fala da expectativa para o debate no Rio
#
#
#         A estratégia de Bolsonaro
#
#
#         'Quem precisa de solução é o povo brasileiro', diz Jair Bolsonaro (PP-RJ)
#
#
#         Boneco gigante de Jair Bolsonaro chama a atenção em Olinda
#
#
#         OAB decide pedir ao STF a cassação do deputado Jair Bolsonaro (PSC)
#
#
#         Jair Bolsonaro (PP-RJ) diz que presidente da Casa precisa entregá-la ao povo brasileiro
#
#
#         STF aceita denúncia contra Jair Bolsonaro por incitar estupro
#
#
#         Processo contra Jair Bolsonaro se arrasta no Conselho de Ética
#
#
#         Veja a programação de agosto da GloboNews
#
#
#         JPB2JP: Confusão durante audiência pública na Câmara de Vereadores de JP
#
#
#         Após advertência, Jean Wyllys diz que cuspiria de novo em Bolsonaro
#
#
#         'Sou especialista em passar em frestas', diz Marina sobre o pouco tempo que terá na propaganda eleitoral
#
#
#         Ministro Barroso será relator único de contestações à candidatura de Lula
#
#
#         Candidatura de Lula será a última a ter registro publicado no 'Diário de Justiça'
#
#
#         Navios portugueses e brasileiros fizeram mais de 9 mil viagens com escravos da África para o Brasil
#
#
#         Candidatos à Presidência da República nas eleições de 2018: veja quem são
#
#
#         'K.O.' volta para o canal no YouTube de Pabllo Vittar: 'me aceita'
#
#
#         Conselho rejeita suspensão, mas adverte Jean Wyllys por cuspe em Bolsonaro
#
#
#         Parentes de cabo e soldado mortos em operação falam da dedicação à carreira militar
#
#
#         Presidenciáveis arrecadam R$ 1,3 milhão com 'vaquinhas virtuais', mostra levantamento; três candidatos têm 90%
#
#
#         Queima do Alho faz resgate à cultura caipira na Festa do Peão de Barretos, SP
#
#
#         Veja o que é #FATO ou #FAKE na entrevista de Ciro Gomes para a GloboNews
#
#
#         Procuradoria acusa Maura Jorge de propaganda eleitoral antecipada no Maranhão
#
#
#         Partido Verde também pede cassação do deputado Jair Bolsonaro
#
#
#         Votação do impeachment: veja como foi o voto de Jair Bolsonaro
#
#
#         Presidenciáveis arrecadam R$ 1,3 milhão com 'vaquinhas virtuais', mostra levantamento; três candidatos têm 90%
#
#
#         Marina e Bolsonaro têm desempenho melhor entre evangélicos, diz Datafolha
#
#
#         OAB-RJ pede cassação do mandato do deputado Jair Bolsonaro
#
#
#         Jair Bolsonaro chuta boneco de Lula durante manifestação em Copacabana, no Rio
#
#
#         Ativistas protestam na porta do condomínio de Jair Bolsonaro, no Rio
#
#
#         Maura Jorge sofre nova representação do MPE por propaganda eleitoral antecipada
#
#
#         Conselho de Ética abre processo disciplinar contra Jair Bolsonaro por apologia à tortura
#
#
#         OAB-RJ vai ao STF pedir a cassação do mandato de Jair Bolsonaro
#
#
#         Militantes protestam contra deputado Jair Bolsonaro na Assembleia Legislativa em Palmas
#
#
#         Conselho de Ética da Câmara abre processo disciplinar contra Jair Bolsonaro
#
#
#         Primeiro debate tem poucas propostas; Mais de 63 mil homicídios em um ano no Brasil. Jornais de sexta (10)
#
#
#         Deputado Jair Bolsonaro agora é réu no STF acusado de apologia ao estupro
#
#
#         Ao escolherem vices, candidatos à Presidência miram voto feminino
#
#
#         OAB decide pedir ao STF a cassação do deputado Jair Bolsonaro
#
#
#         OAB-RJ irá ao STF para pedir a cassação do deputado Jair Bolsonaro
#
#
#         Ao escolherem vices, candidatos à Presidência miram voto feminino
#
#
#         Há cura para a polarização política
#
#
#         Seis candidatos ao governo da Bahia nas eleições de 2018 participam de primeiro debate na TV
#
#
#         Confusão durante audiência pública em João Pessoa com Jair Bolsonaro
#
#
#         Câmara aprova pela primeira vez emenda de Jair Bolsonaro
#
#
#         Manifestantes fazem ato contra cassação do mandato do deputado estadual Jair Bolsonaro.
#
#
#         Manifestantes realizam ato na Praia de iracema contra deputado estual Jair Bolsonaro
#
#
#         Em Belém, manifestantes que apoiam Jair Bolsonaro trocam ofensas com grupo ligado à CUT
#
#
#         Jovem é detido após tentar agredir o deputado Jair Bolsonaro
#
#
#         TSE registra 13 inscritos para disputar a presidência em outubro
#
#
#         OAB-RJ protocola pedido de cassação do mandato do deputado Jair Bolsonaro
#
#
#         Manifestantes fazem ato na frente da casa do deputado Jair Bolsonaro no Rio
#
#
#         Instituto Vladimir Herzog divulga nota de repúdio a discurso de Jair Bolsonaro
#
#
#         Governo Temer tem aprovação de 4% e reprovação de 79%, diz Ibope
#
#
#         Ministério Público denuncia Jair Bolsonaro por incitação ao estupro
#
#
#         G1 em 1 Minuto: Conselho de Ética da Câmara abre processo contra deputado Jair Bolsonaro
#
#
#         Empresas se protegem contra alta do dólar; Bolsonaro não consegue apoio de outros partidos. Jornais de quinta (19)
#
#
#         Jair Bolsonaro vira réu no STF por incitação ao estupro e injúria contra Maria do Rosário
#
#
#         Haddad é o candidato real do PT
#
#
#         Jovem é detido após tentar agredir o deputado Jair Bolsonaro
#
#
#         Pesquisa Datafolha para o Senado no Rio de Janeiro: Cesar Maia, 18%; Flávio Bolsonaro, 18%; Lindbergh, 18%; Chico Alencar 17%
#
#
#         Marco Aurélio Mello libera para julgamento a denúncia de racismo contra Bolsonaro
#
#
#         Veja o que é #FATO ou #FAKE nas falas dos candidatos ao governo de SP no debate da Band
#
#
#         Candidatos ao Senado pelo RJ nas eleições de 2018: veja quem são
#
#
#         Carmén defende fim de benefícios a juízes; Crise turca afeta bolsa e dólar no Brasil. Jornais de sábado (11)
#
#
#         Jair Bolsonaro diz que governo usaria hipotético ataque terrorista para não deixar o poder
#
#
#         PT confirma Lula na disputa; Alckmin terá 44% do tempo de TV. Jornais de domingo (5)
#
#
#         Bloqueios em avenidas deixam trânsito lento no Centro de Ponta Grossa
#
#
#         MP denuncia Bolsonaro pelo crime de incitação ao estupro
#
#
#         Bolsonaro é a essência do machão parado no tempo
#
#
#         Brasil herdou 'malandragem' do africano, diz Mourão, vice na chapa de Bolsonaro
#
#
#         ‘Declaração de Mourão fornece munição para adversários de Bolsonaro’, diz Valdo
#
#
#         Alunos da Unicamp protestam contra sobre crise política e o corte de verbas na educação
#
#
#         JN traz detalhes de investigação envolvendo avião que caiu e matou Eduardo Campos
#
#
#         Demitida a secretária parlamentar que vendia açaí no Rio de Janeiro
#
#
#         Divulgada pesquisa CNI-Ibope com a intenção de voto para a Presidência da República
#
#
#         Deputado solta morteiros em frente a hotel na Barra
#
#
#         Diálogos: Maria do Rosario fala de crise, reforma, Lava-Jato, direitos e Bolsonaro
#
#
#         PT, PRTB e PDT anunciam nomes dos vices nas chapas à presidência da república
#
#
#         Vice de Bolsonaro diz que foi mal interpretado e que não é racista
#
#
#         Deputados que ainda não votaram são citados no Plenário da Câmara
#
#
#         ‘Quanto mais Mourão explica, pior fica’, diz Merval
#
#
#         Sessão vai definir novo presidente da Câmara dos Deputados
#
#
#         Site da Prefeitura de Jaú fica fora do ar após ataque de hackers
#
#
#         Bolsonaro não consegue fechar coligações e fica isolado na busca por alianças
#
#
#         Marco Aurélio Mello libera para julgamento a denúncia de racismo contra Bolsonaro
#
#
#         Governo Temer tem aprovação de 4% e reprovação de 79%, diz Ibope
#
#
#         Estudantes realizam protesto na Câmara contra Bolsonaro
#
#
#         Conselho de Ética abre processo por quebra de decoro contra Bolsonaro
#
#
#         Filhos de Bolsonaro dizem que pai não é preconceituoso
#
#
#         PRTB oficializa apoio a Bolsonaro à Presidência e general Mourão como candidato a vice
#
#
#         Bolsonaro diz que será candidato em 2018, 'gostem ou não gostem'
#
#
#         Bolsonaro entrega defesa à Corregedoria da Câmara
#
#
#         A estratégia de Bolsonaro
#
#
#         Corregedoria recebe quatro representações contra Bolsonaro
#
#
#         Lula cresce e, sem o petista, Bolsonaro lidera pesquisa; Marina e Ciro disputam segundo lugar. Jornais de terça (21)
#
#
#         Bolsonaro vai responder por apologia à tortura, no Conselho de Ética
#
#
#         Deputado do PSC será relator de ação contra Bolsonaro
#
#
#         Conselho de Ética da Câmara arquiva processos sobre Eduardo Bolsonaro
#
#
#         Bolsonaro é notificado por Corregedoria da Câmara
#
#
#         Bolsonaro lança candidatura à presidência da Câmara; agora são 3
#
#
#         Em programa de governo, Bolsonaro diz que vai criar Ministério da Economia
#
#
#         Deputado Bolsonaro cria polêmica por causa de ideias anti-gays no Senado
#
#
#         Bolsonaro lança candidatura à presidência da Câmara; agora são 3
#
#
#         Associação de gays entra com representação contra Bolsonaro
#
#
#         Denúncia da PGR contra Bolsonaro já está com ministra Rosa Weber, do STF
#
#
#         Senadora do PSOL entra com representação contra Bolsonaro
#
#
#         Na Câmara, Bolsonaro se diz vítima de preconceito por ser heterossexual
#
#
#         Dupla de topless usa boneco de Bolsonaro para protestar no Rio
#
#
#         Bolsonaro participa de ato a favor do impeachment na Praia de Camburi
#
#
#         PSOL protocola representação contra Bolsonaro no Conselho de Ética
#
#
#         OAB pede à Procuradoria da República medidas contra Bolsonaro
#
#
#         STF rejeita recurso e mantém Bolsonaro réu por suposta incitação ao estupro
#         Eleições de outubro vão ter 13 candidatos à Presidência da República
#
#
#         Temporada de convenções termina neste domingo; 5 partidos definirão presidenciáveis ou alianças
#
#
#         Lula deve aparecer nas pesquisas?
#
#
#         'K.O.' volta para o canal no YouTube de Pabllo Vittar: 'me aceita'
#
#
#         Jair Bolsonaro joga água em manifestante de grupo gay
#
#
#         Marcio Lacerda diz que mantém candidatura ao governo de MG pelo PSB
#
#
#         Quatro presidenciáveis e um vice apresentam propostas em sabatina do setor de comércio e serviços
#
#
#         Conselho de Ética abre processo disciplinar contra Jair Bolsonaro
#
#
#         Quarta-feira, 8 de agosto
#
#
#         Queima do Alho faz resgate à cultura caipira na Festa do Peão de Barretos, SP
#
#
#         'Centrão' quer Josué Gomes como vice em chapa com Ciro ou Alckmin
#
#
#         Conselho de Ética rejeita abertura de processo contra Jair Bolsonaro
#
#
#         Terça-feira, 7 de agosto
#
#
#         Partidos têm de solucionar até domingo impasse sobre candidatos a vice-presidente, reafirma TSE
#
#
#         PR aprova apoio a tucano Geraldo Alckmin na disputa pela Presidência
#
#
#         Guardia debate frágil situação fiscal no ano da eleição com economistas ligados à Rede e ao DEM
#
#
#         Deputado Jair Bolsonaro oficializa candidatura à presidência da Câmara
#
#
#         Sexta-feira, 10 de agosto
#
#
#         Imagens do dia 31 de julho de 2018
#
#
#         Ministra espera 'firmeza' da Câmara em relação a Jair Bolsonaro
#
#
#         Deputado Jair Bolsonaro é lembrado na Parada Gay
#
#
#         STF investiga se o deputado Jair Bolsonaro cometeu crime de racismo
#
#
#         Você viu? Acidentes com aviões no Campo de Marte e no México e outras notícias da semana
#
#
#         Cultura de doações por empresa dificulta adesão às 'vaquinhas eleitorais', avalia especialista
#
#
#         Lula tem 25%, Marina 15% e Aécio 11%, aponta pesquisa Datafolha para 2018
#
#
#         2 de agosto, quinta-feira
#
#
#         Nego do Borel fala sobre clipe de 'Me solta': 'Sabia que poderia ser algo polêmico, mas fui em frente'
#
#
#         Jair Bolsonaro quer ir ao Conselho de Ética explicar declarações
#
#
#         Após ameaças de divisão, Centrão fecha com Alckmin para tentar chegar ao segundo turno
#
#
#         Após advertência, Jean Wyllys diz que cuspiria de novo em Bolsonaro
#
#
#         Conselho rejeita suspensão, mas adverte Jean Wyllys por cuspe em Bolsonaro
#
#
#         Geraldo Alckmin diz que avalia extinguir Ministério do Trabalho se for eleito
#
#
#         Cinco presidenciáveis apresentam em SP propostas sobre tecnologia e inovação
#
#
#         O despertar de Alckmin
#
#
#         Denúncia da PGR contra Bolsonaro já está com ministra Rosa Weber, do STF
#
#
#         Cinco presidenciáveis apresentam propostas em sabatina do setor da construção civil
#
#
#         Posições de Ciro sobre economia podem definir destino do 'Centrão' na eleição presidencial
#
#
#         3 de agosto, sexta-feira
#
#
#         Sexta-feira, 3 de agosto
#
#
#         TSE rejeita pedido de Bolsonaro para inserir esclarecimento em pesquisa do Datafolha
#
#
#         À espera da decisão do "centrão"
#
#
#         Conversas do 'Blocão' com Alckmin 'evoluíram bastante', diz ACM Neto
#
#
#         Vendedora de açaí deixa cargo de secretária parlamentar de Bolsonaro
#
#
#         Quarta-feira, 1º de agosto
#
#
#         Imagens da semana de 28 de julho a 3 de agosto de 2018
#
#
#         Janaína Paschoal recusa convite para ser vice de Bolsonaro
#
#
#         Procuradoria Eleitoral propõe multa a Lula e a Bolsonaro por propaganda antecipada
#
#
#         PSOL quer processar Bolsonaro na Câmara por suposta agressão
#
#
#         Chegada de Bolsonaro é marcada por confusão no aeroporto de Vitória
#
#
#         Doria, Bolsonaro ou Alckmin?
#
#
#         STF arquiva inquérito contra Bolsonaro por falas sobre Preta Gil
#
#
#         'Ele estaria dormindo até agora', diz Bolsonaro sobre soco em Randolfe
#
#
#         Procuradoria vê incitação ao estupro e denuncia Bolsonaro ao STF
#
#
#         Alunos da UFC fazem ato pró e contra Bolsonaro na reitoria da universidade
#
#
#         Corregedoria notifica Bolsonaro em investigação por racismo e homofobia
#
#
#         Justiça do DF condena Bolsonaro a pagar R$ 10 mil a Maria do Rosário
#
#
#         Conselho de Ética processa Bolsonaro por apologia à tortura
#
#
#         Ato em Fortaleza protesta contra impeachment e deputado Bolsonaro
#
#
#         Com apoio de Feliciano, Bolsonaro quer Comissão de Direitos Humanos
#
#
#         Quatro partidos pedem ao Conselho de Ética a cassação de Bolsonaro
#
#
#         Pesquisa com Lula tem valor?
#
#
#         Conheça os principais pré-candidatos à Presidência já declarados
#
#
#         Jairzinho lança música em homenagem ao pai, Jair Rodrigues
#
#
#         Diálogos: Maria do Rosario fala de crise, reforma, Lava-Jato, direitos e Bolsonaro
#
#
#         Declaração de Mourão, candidato a vice de Bolsonaro, causa protestos
#
#
#         Dólar fecha em queda, no patamar de R$ 3,85, com exterior
#
#
#         JPB2JP: Confusão durante audiência pública na Câmara de Vereadores de JP
#
#
#         Deputados elegem nesta quinta presidente da Câmara para os próximos dois anos
#
#
#         Lula perde votos e Marina empata com Bolsonaro; Rio erra de novo com Royalties. Jornais de domingo (15)
#
#
#         Economia fraca prejudica candidatos de centro, que seguem divididos
#
#
#         Flávio Bolsonaro é anunciado como candidato do PSC à Prefeitura
#
#
#         Fux acha possível julgar ações contra Bolsonaro nos próximos seis meses
#
#
#         Vice-presidente do TSE libera outdoors de apoio a Bolsonaro na Bahia
#
#
#         Empresas buscam proteção após alta do dólar; 1/3 dos eleitores não têm candidato no cenário sem Lula. Jornais de domingo (10)
#
#
#         Candidato a vice na chapa de Bolsonaro diz que foi mal-entendido
#
#
#         Vice de Bolsonaro diz que Brasil herdou 'indolência' do índio e 'malandragem' do africano
#
#
#         Major Olimpio convida policial que matou bandido em frente a escola de SP para ser candidata pelo PSL
#
#
#         Candidato a vice na chapa de Bolsonaro diz que foi mal-entendido
#
#
#         Marina critica Bolsonaro, Alckmin quer Aécio fora da eleição e Barbosa prepara programa. Jornais de quinta (19)
#
#
#         G1 em 1 Minuto: sai 1ª pesquisa Ibope para presidente após registro das candidaturas
#
#
#         Eleição permanece indefinida
#
#
#         Polarização e democracia no Brasil
#
#
#         Presidenciáveis não falam sobre Previdência; Maia indica fim da aliança entre DEM e PSDB. Jornais de domingo (13)
#
#
#         Cristiana Lôbo comenta abertura de processo contra Bolsonaro
#
#
#         Bolsonaro vira réu por incitação ao estupro
#
#
#         Janaína Paschoal recusa convite para ser vice de Bolsonaro
#
#
#         Conselho de Ética livra Bolsonaro de processo por quebra de decoro em homenagem a Ustra
#
#
#         STJ nega pedido de habeas corpus de Lula; Bolsonaro lidera em cenário sem ex-presidente. Jornais de quarta (31)
#
#
#         Haddad é vice de Lula, Katia Abreu, de Ciro, e general, de Bolsonaro; Manuela sai a pedido do PT. Jornais de segunda (6)
#
#
#         Quem herdará o espólio de Lula?
#
#
#         Bolsonaro diz que entrará no 'armário do silêncio' se for punido
#
#
#         Após insultos racistas e homofóbicos, homem é detido em manifestação contra Bolsonaro em BH
#
#
#         Para OAB, Bolsonaro deve ser processado por quebra de decoro
#
#
#         Ato pró-Bolsonaro acaba em prisão na Avenida Paulista
#
#
#         Flávio Bolsonaro deixa debate entre candidatos no Rio após passar mal
#
#
#         Manifestantes fazem protesto no Rio contra declarações de Bolsonaro
#
#
#         Bolsonaro anuncia general Hamilton Mourão como vice
#
#
#         Sociedade foi 'desinformada sobre verdade', diz Bolsonaro após virar réu
#
#
#         Conselho de Ética sorteia três nomes para relator do processo de Bolsonaro
#
#
#         Relator vota pela continuidade de processo de Bolsonaro no Conselho
#
#
#         Lula tem 30%, Bolsonaro, 15%, e Marina, 14%, aponta pesquisa Datafolha para 2018
#
#
#         Instituto Vladimir Herzog pede cassação de Bolsonaro
#
#
#         Bolsonaro vira réu por falar que Maria do Rosário não merece ser estuprada
#
#
#         Conselho de Ética da Câmara recebe amanhã parecer do caso Bolsonaro
#
#
#         Deputados querem cassar Medalha Tiradentes de Bolsonaro no RJ
#
#
#         STJ mantém condenação de Bolsonaro por ofensas a Maria do Rosário
#
#
#         OAB quer cassar deputado por homenagem a acusado de tortura
#
#
#         O dólar deve gerar pânico?
#
#
#         O paradoxo eleitoral de 2018
#
#
#         G1 em 1 Minuto: Câmara aprova MP que libera controle estrangeiro de empresa aérea no país
#
#
#         Bolsonaro é confirmado como candidato à presidência em convenção de partido
#
#
#         Regularização de terras aumenta; Mercado vê Bolsonaro como opção a Lula. Jornais de domingo (12)
#
#
#         Técnico Jair Ventura é demitido do Santos
#
#
#         Jair Ventura não é mais o técnico do Santos
#
#
#         Estudante nega ter premeditado 'ovada' em Bolsonaro durante visita a Ribeirão
#
#
#         Santos F.C. demite Jair Ventura
#
#
#         Líderes de cinco partidos entram com representação criminal na PGR contra Bolsonaro
#
#
#         PEN e PP são protagonistas das últimas contradições na política brasileira
#
#
#         Conselho de Ética da Câmara arquiva processos sobre Eduardo Bolsonaro
#
#
#         Ministério Público Eleitoral pede retirada de outdoor de apoio a Bolsonaro em MT
#         Ministério Público Eleitoral pede retirada de outdoor de apoio a Bolsonaro em MT
#
#
#         Bolsonaro é alvo de vaias e aplausos na arena da Festa do Peão de Barretos
#
#
#         Após insultos racistas e homofóbicos, homem é detido em manifestação contra Bolsonaro em BH
#
#
#         15 dos 20 presidenciáveis têm processos na Justiça; 90% dos deputados tentarão se reeleger. Jornais de domingo (22)
#
#
#         Seis nomes disputam a Presidência
#
#
#         Pedido de cassação de Bolsonaro ganha reforço
#
#
#         Fux intima Maria do Rosário a depor na ação em que Bolsonaro é réu
#
#
#         Após depor ao STF, Maria do Rosário diz que Bolsonaro é 'líder do ódio'
#
#
#         Elite do Exército atua na intervenção; Concessionárias de rodovias não respeitam contratos. Jornais de domingo (25)
#
#
#         Bolsonaro fica inelegível após STJ manter condenação por ofensas a Maria do Rosário? Não é verdade!
#
#
#         Alunos da Unicamp protestam contra sobre crise política e o corte de verbas na educação
#
#
#         E se Dilma tivesse ficado?
#
#
#         EUA e aliados bombardeiam a Síria; Economia tem retomada mais lenta. Jornais de sábado (14)
#
#
#         O custo oculto do subsídio
#
#
#         Fórum da Liberdade em Porto Alegre terá palestra de Sérgio Moro e a presença de presidenciáveis
#
#
#         Professor é ameaçado por ex-aluno no RS após post contra Bolsonaro
#
#
#         Projeto que prevê punições para homofobia gera confusão no Senado
#
#
#         Após polêmica, faculdade do DF nega ter marcado palestra com Bolsonaro; deputado confirma
#
#
#         Lula avança e Bolsonaro se firma em segundo para 2018; Rede lança Marina. Jornais de domingo (3)
#
#
#         ‘Tu deveria ir pra cadeia’, diz senadora a Bolsonaro no Congresso
#
#
#         General Mourão é solução caseira após tentativas frustradas de Bolsonaro para encontrar um vice
#
#
#         Grupos protestam contra deputado Bolsonaro em homenagem no AM
#
#
#         Relator do processo de Bolsonaro no Conselho de Ética é definido
#
#
#         Conselho de Ética abre processo para decidir sobre cassação de Bolsonaro
#
#
#         Alves diz que Bolsonaro tinha direito de falar em sessão sobre a ditadura
#
#
#         Lula tem 31%, Bolsonaro, 15%, Marina, 10%, aponta pesquisa Datafolha para 2018
#
#
#         TSE rejeita pedido de Bolsonaro para inserir esclarecimento em pesquisa do Datafolha
#
#
#         Bolsonaro processa padre Júlio Lancelotti e pede R$ 50 mil por danos morais
#
#
#         Após declaração polêmica, vice de Bolsonaro se autodeclara indígena ao TSE
#
#
#         Marina e Bolsonaro têm desempenho melhor entre evangélicos, diz Datafolha
#
#
#         Bovespa fecha em queda com exterior e noticiário político
#
#
#         Ato contra Lula fecha ruas do Centro de Campinas
#
#
#         Bolsonaro processa padre Júlio Lancelotti e pede R$ 50 mil por danos morais
#
#
#         A fragmentação do campo antipetista
#
#
#         Comece a semana bem informado: as notícias de sábado (14) e domingo (15)
#
#
#         Como a crise da Venezuela influencia as campanhas presidenciais na Colômbia, no México e no Brasil
#
#
#         Ex-prefeito Jair Siqueira é sepultado em Pouso Alegre, MG
#
#
#         STF rejeita recurso e mantém Bolsonaro réu por suposta incitação ao estupro
#
#
#         Juventude pode perder volante para o Sport.
#
#
#         Ex-prefeito de Pouso Alegre, Jair Siqueira morre aos 82 anos
#
#
#         Com máscaras de Bolsonaro, 'beijaço' protesta contra 'cura gay' em festival de música em Natal; veja vídeo
#
#
#         Dois ônibus da caravana de Lula são alvos de tiros; STF reforça segurança de Fachin.Jornais de quarta (28)
#
#
#         Bolsonaro anuncia 'noivado' com o PEN e cobra retirada de ação do partido que corre no STF
#
#
#         O risco da candidatura Huck
#
#
#         Governo gastou R$ 43 bi com gratificação a servidor federal; Planalto se divide entre Temer e Meirelles. Jornais de domingo (11)
#
#
#         Protesto em escola liga exoneração de diretora a critica a Bolsonaro
#
#
#         PGR propõe arquivar inquérito para apurar suposto racismo de Bolsonaro
#
#
#         Integrantes do STF demonstram preocupação com proposta de Bolsonaro de ampliar de 11 para 21 os ministros da Corte
#
#
#         Ato com manifestantes pró e contra Bolsonaro tem tumulto e bomba de efeito moral em Florianópolis
#
#
#         Banda Francisco, El Hombre ironiza Bolsonaro em faixa com gay Liniker
#
#
#         Polarização e democracia no Brasil
#
#
#         'Não tento agradar', diz Bolsonaro, o deputado federal mais votado no RJ
#
#
#         Cunha rejeita pedido de Bolsonaro para processo impeachment de Dilma
#
#
#         STJ nega pedido de habeas corpus de Lula; Bolsonaro lidera em cenário sem ex-presidente. Jornais de quarta (31)
#
#
#         'Sou obrigado a elogiar a Dilma', diz Bolsonaro sobre suspensão de kit
#
#
#         Grávida torturada por Ustra diz que voto de Bolsonaro incita crime
#
#
#         Aécio tem 26%, Lula, 20% e Marina, 19%, diz pesquisa Datafolha
#
#
#         Fernando Meirelles diz que Trump e Bolsonaro odiarão abertura dos Jogos
#
#
#         Deputado associa na TV namoro com negras a 'promiscuidade'
#
#
#         Com máscaras de Bolsonaro, 'beijaço' protesta contra 'cura gay' em festival de música em Natal; veja vídeo
#
#
#         Que agenda dominará a eleição?
#
#
#         Bancada da Câmara dos Deputados tem maior renovação desde 1998
#
#
#         PPL anuncia pré-candidatura de João Vicente Goulart à Presidência da República
#
#
#         Fórum da Liberdade em Porto Alegre terá Sérgio Moro e presidenciáveis nesta segunda e terça
#
#
#         A Constituição prevê a possibilidade de uma intervenção militar?
#
#
#         Twitter da FAB publica mensagem sobre Bolsonaro e depois apaga
#
#
#         TSE abre nova licitação para voto impresso, mas pede ao STF para derrubar implantação do sistema
#
#
#         Conselho de Ética da Câmara arquiva processo contra Bolsonaro
#
#
#         Ato com manifestantes pró e contra Bolsonaro tem tumulto e bomba de efeito moral em Florianópolis
#
#
#         Marcela Ross NÃO existe, pesquisa NÃO mostra 94% de apoio à intervenção militar e país NÃO está em estado de sítio: como funciona uma das fábricas de fake news no Brasil
#
#
#         MP denuncia Bolsonaro pelo crime de incitação ao estupro
#
#
#         Alckmin usa discurso para iniciar polarização com Lula
#
#
#         Bolsonaro vai responder por apologia à tortura, no Conselho de Ética
#
#
#         Após polêmica, faculdade do DF nega ter marcado palestra com Bolsonaro; deputado confirma
#
#
#         Neymar é marcado na área musical com funk-exaltação composto por Jair Oliveira
#
#
#         Neymar é marcado na área musical com funk-exaltação composto por Jair Oliveira
#
#
#         Debate sobre violência contra mulher resulta em tumulto com Bolsonaro
#
#
#         Perícia refuta legenda de vídeo de Bolsonaro contra Jean Wyllys sobre cuspe
#
#
#         Combate à corrupção será tema primordial nas eleições, diz cientista político da UnB; leia entrevista
#
#
#         Flávio Bolsonaro é confirmado como candidato do PSC a prefeito do Rio
#
#
#         Conselho de Ética arquiva processo de Bolsonaro por homenagem a Ustra
#
#
#         Sem criação da Palestina, Israel viverá apartheid, diz rabino progressista no Brasil
#
#
#         Temer criou-se uma armadilha
#
#
#         Pelo menos 80 deputados trocam de legenda durante a janela partidária
#
#
#         PRB anuncia pré-candidatura de Flávio Rocha à Presidência da República
#
#
#         Até onde irá a violência política?
#
#
#         Câmara tem confusão em cerimônia que lembrou os 50 anos do golpe militar
#
#
#         Marielle e a política
#
#
#         Segurança dominará campanha
#
#
#         PT e PMDB formam aliança em 6 estados; TSE julga antecipação de campanha. Jornais de sábado (4)
#
#
#         Candidato Flávio Bolsonaro vota em seção eleitoral na Tijuca, no Rio
#
#
#         A história da primeira criança trans que conseguiu alterar os documentos no Brasil
#
#
#         PDT lança pré-candidatura de Ciro Gomes à Presidência da República
#
#
#         Multidão faz carreata e lota aeroporto de Fortaleza para receber Bolsonaro
#
#
#         Ex-prefeito Jair Siqueira morre de pneumonia em Pouso Alegre (MG)
#
#
#         Corpo de ex-prefeito de Pouso Alegre, Jair Siqueira, é velado
#
#
#         Corpo de PM que morreu afogado durante perseguição é enterrado em Lorena
#
#
#         O caminho tortuoso do centro
#
#
#         Bolsonaro discute com ativistas em comissão
#
#
#         Relator vota pela continuidade de processo de Bolsonaro no Conselho
#
#
#         Bolsonaro participa de ato a favor do impeachment na Praia de Camburi
#
#
#         Conselho adia escolha de relator do processo de cassação de Bolsonaro
#
#
#         Deputado Odorico Monteiro relatará processo de cassação de Bolsonaro
#
#
#         Parlamentares discutem na porta do antigo DOI-Codi
#
#
#         Flávio Bolsonaro volta à campanha e fala em 'enxugar máquina'
#
#
#         Chico Alencar é 4o candidato à presidência da Câmara
#
#
#         Presidente de comissão diz que pedirá investigação de deputado pastor
#
#
#         Relator sugere arquivamento do pedido de cassação de Jean Wyllys
#
#
#         Elite do Exército atua na intervenção; Concessionárias de rodovias não respeitam contratos. Jornais de domingo (25)
#
#
#         Chico Alencar é 4o candidato à presidência da Câmara
#
#
#         Associação entra com nova ação no Supremo contra Mais Médicos
#
#
#         Alunos denunciam pichações homofóbicas e machistas na Universidade Mackenzie
#
#
#         Governo diz ao STF que MP do Mais Médicos é necessária e inadiável
#
#
#         A caça ao voto indefinido
#
#
#         Veja o patrimônio que os candidatos a presidente declararam ao TSE
#
#
#         Movimento Gay faz ato público na BA contra declarações de deputado
#
#
#         MEC nega boato sobre distribuição de livro de educação sexual a escolas
#
#
#         Os efeitos da candidatura Maia
#
#
#         PRP decide apoiar pré-candidatura de Álvaro Dias, do Podemos, à Presidência
#
#
#         ‘Vamos para o corpo a corpo’, diz líder petista sobre disputa na Câmara
#         Por que o populismo está crescendo na direita e na esquerda?
#
#
#         PV entra com representação no Conselho de Ética contra Bolsonaro
#
#
#         Alunos da UFC fazem ato pró e contra Bolsonaro na reitoria da universidade
#
#
#         Motivação política não impede sucesso de operação no Rio, diz historiador
#
#
#         Em nota, OAB 'repudia' voto de Bolsonaro que homenageou Ustra
#
#
#         Duas pessoas são presas em operação da polícia que apreendeu submetralhadora e droga, em Sarandi
#
#
#         Chegada de Bolsonaro é marcada por confusão no aeroporto de Vitória
#
#
#         Ato em Fortaleza protesta contra impeachment e deputado Bolsonaro
#
#
#         Conselho de Ética sorteia três nomes para relator do processo de Bolsonaro
#
#
#         Jean Wyllys vira alvo do Conselho de Ética por cuspir em Bolsonaro
#
#
#         Presidentes de comissões pedem processo de cassação de Bolsonaro
#
#
#         Sociedade foi 'desinformada sobre verdade', diz Bolsonaro após virar réu
#
#
#         Casal gay protagoniza beijo durante chegada de Bolsonaro a Santos, SP
#
#
#         Pré-candidatos à Presidência apresentam propostas em evento no Rio Grande do Sul
#
#
#         Bolsonaro vira réu por falar que Maria do Rosário não merece ser estuprada
#
#
#         Pré-candidatos à Presidência apresentam propostas em evento no Rio Grande do Sul
#
#
#         Conselho da OAB avaliará declaração de Bolsonaro sobre torturador
#
#
#         Bissexual que elogiou Bolsonaro em rede social tem casa atacada em MT
#
#
#         Flávio Bolsonaro é entrevistado no RJTV
#
#
#         Bissexual denuncia ameaças após post de apoio a Bolsonaro em MT
#
#
#         Taróloga apresenta as previsões para o ano de 2018
#
#
#         Políticos e entidades criticam ataque à caravana de Lula no Paraná; veja repercussão
#
#
#         Quarta-feira, 28 de março de 2018
#
#
#         A escolha do novo presidente, a grande aposta para 2018
#
#
#         O que concluir do Datafolha
#
#
#         Brexit, Trump e Bolsonaro
#
#
#         Relator vota no Conselho de Ética pela continuidade de processo que apura se Wladimir Costa cometeu assédio
#
#
#         Alckmin é quase atingido por ovada no Centro de São Paulo
#
#
#         Deputados querem cassar Medalha Tiradentes de Bolsonaro no RJ
#
#
#         PT aciona Conselho de Ética da Câmara contra deputado Wladimir Costa
#
#
#         PT aciona Conselho de Ética da Câmara contra deputado Wladimir Costa
#
#
#         Justiça do DF mantém condenação de Bolsonaro por ofensas a deputada
#
#
#         Conselho faz sorteio para relatoria do processo de cassação de Bolsonaro
#
#
#         Instituto Vladimir Herzog pede cassação de Bolsonaro
#
#
#         Jair Rodrigues, cantor do tamanho do sorriso farto, tem reeditados oito álbuns do período 1972 – 2001
#
#
#         Deputado solta morteiros em frente a hotel na Barra
#
#
#         Líderes de 5 partidos e filho de Herzog acionam PGR contra Bolsonaro
#
#
#         Quem será presidente em 2018?
#
#
#         Banda Francisco, El Hombre ironiza Bolsonaro em faixa com gay Liniker
#
#
#         Hacker coloca foto de Bolsonaro e Hitler no site do Porto de Vitória
#
#
#         OAB-RJ aciona Câmara para pedir cassação de Bolsonaro por citar Ustra
#
#
#         Conselho arquiva processo que analisava cassação de Jean Wyllys
#
#
#         Manifestantes pró e contra Bolsonaro causam tumulto na Assembleia
#
#
#         O autoritarismo do brasileiro
#
#
#         Professor é ameaçado por ex-aluno no RS após post contra Bolsonaro
#
#
#         Deputado pede vista, e Conselho adia votação sobre processo de Jean Wyllys
#
#
#         Quinta-feira, 9 de novembro de 2017
#
#
#         Precisamos de mais pesquisas
#
#
#         Protesto em escola liga exoneração de diretora a critica a Bolsonaro
#
#
#         Maria do Rosário diz que vai doar valor de indenização de Bolsonaro
#
#
#         As incógnitas eleitorais para 2018
#
#
#         Ao renunciar, vice-governador de RR compara venezuelanos a zumbis: 'ruas lembram The Walking Dead'
#
#
#         Após 'beijaço gay', grupos entram em confronto em evento com Bolsonaro
#
#
#         Fernando Meirelles diz que Trump e Bolsonaro odiarão abertura dos Jogos
#
#
#         Justiça do DF condena Bolsonaro a pagar R$ 10 mil a Maria do Rosário
#
#
#         Geraldo Alckmin faz campanha em indústria de cereais no interior do Tocantins
#
#
#         Cartaz com foto de Bolsonaro é colada na Ufac com frase 'cuspe ao alvo'
#
#
#         Doria reduzirá viagens pelo país
#
#
#         Terça-feira, 15 de agosto de 2017
#
#
#         Alunos denunciam pichações homofóbicas e machistas na Universidade Mackenzie
#
# 600

# %%
tuplesToInsert = []

for news in allNewsArray:
    tuplesToInsert.append([news.title])
    

outfile = open('./exportedData3.csv','w',encoding='utf-8')
outfile.truncate()

csvWriter = csv.writer(outfile, delimiter=';')

csvWriter.writerow(['title'])

for news in allNewsArray:
    data = news.title.strip()
    csvWriter.writerow([data])

# %%
news_data = []
for link in links:
    title, texto = webPageScrapper.access(link)
    news_data.append({'title': title, 'content': texto})

for news in news_data:
    print(news['title'], '\n\n', news['content'], '\n\n\n')

# %% [markdown]
# ### Calculando estatísticas básicas de cada notícia coletada (news_data)

# %%
import sys
import json
import nltk



stop_words = nltk.corpus.stopwords.words('portuguese') + [
    '.',
    ',',
    '--',
    '\'s',
    '?',
    ')',
    '(',
    ':',
    '\'',
    '\'re',
    '"',
    '-',
    '}',
    '{',
    ]

for news in news_data:
    sentences = nltk.tokenize.sent_tokenize(news['content'])

    words = [w.lower() for sentence in sentences for w in
             nltk.tokenize.word_tokenize(sentence)]

    fdist = nltk.FreqDist(words)

    # Basic stats

    num_words = sum([i[1] for i in fdist.items()])
    num_unique_words = len(fdist.keys())

    # Hapaxes are words that appear only once

    num_hapaxes = len(fdist.hapaxes())

    top_10_words_sans_stop_words = [w for w in fdist.items() if w[0]
                                    not in stop_words][:10]

    print(news['title'])
    print('\tNum Sentences:'.ljust(25), len(sentences))
    print('\tNum Words:'.ljust(25), num_words)
    print('\tNum Unique Words:'.ljust(25), num_unique_words)
    print('\tNum Hapaxes:'.ljust(25), num_hapaxes)
    print('\tTop 10 Most Frequent Words (sans stop words):\n\t\t', \
            '\n\t\t'.join(['%s (%s)'
            % (w[0], w[1]) for w in top_10_words_sans_stop_words]))
    print()
# Out:
# Entidade pede que Ministério Público do RS analise fala do vice de Bolsonaro sobre negros
# 	Num Sentences:           10
# 	Num Words:               400
# 	Num Unique Words:        216
# 	Num Hapaxes:             167
# 	Top 10 Most Frequent Words (sans stop words):
# 		 entidade (1)
# 		educafro (3)
# 		protocolou (1)
# 		ministério (1)
# 		público (1)
# 		rio (2)
# 		grande (2)
# 		sul (3)
# 		mp-rs (1)
# 		nesta (1)
#
# Após debate morno, estrategistas de Alckmin defendem confrontar Bolsonaro na campanha da TV
# 	Num Sentences:           20
# 	Num Words:               410
# 	Num Unique Words:        199
# 	Num Hapaxes:             142
# 	Top 10 Most Frequent Words (sans stop words):
# 		 primeiro (1)
# 		debate (3)
# 		presidencial (1)
# 		tv (3)
# 		dividiu (1)
# 		opiniões (1)
# 		campanhas (2)
# 		principais (4)
# 		candidatos (1)
# 		servirá (1)

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Igor\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %% [markdown]
# ### Sumarizando as notícias coletadas

# %%
import sys
import json
import nltk
import numpy

N = 100  # Number of words to consider
CLUSTER_THRESHOLD = 5  # Distance between words to consider
TOP_SENTENCES = 5  # Number of sentences to return for a "top n" summary

# Approach taken from "The Automatic Creation of Literature Abstracts" by H.P. Luhn

def _score_sentences(sentences, important_words):
    scores = []
    sentence_idx = -1

    for s in [nltk.tokenize.word_tokenize(s) for s in sentences]:

        sentence_idx += 1
        word_idx = []

        # For each word in the word list...
        for w in important_words:
            try:
                # Compute an index for where any important words occur in the sentence

                word_idx.append(s.index(w))
            except (ValueError) as e: # w not in this particular sentence
                pass

        word_idx.sort()

        # It is possible that some sentences may not contain any important words at all
        if len(word_idx)== 0: continue

        # Using the word index, compute clusters by using a max distance threshold
        # for any two consecutive words

        clusters = []
        cluster = [word_idx[0]]
        i = 1
        while i < len(word_idx):
            if word_idx[i] - word_idx[i - 1] < CLUSTER_THRESHOLD:
                cluster.append(word_idx[i])
            else:
                clusters.append(cluster[:])
                cluster = [word_idx[i]]
            i += 1
        clusters.append(cluster)

        # Score each cluster. The max score for any given cluster is the score 
        # for the sentence

        max_cluster_score = 0
        for c in clusters:
            significant_words_in_cluster = len(c)
            total_words_in_cluster = c[-1] - c[0] + 1
            score = 1.0 * significant_words_in_cluster \
                * significant_words_in_cluster / total_words_in_cluster

            if score > max_cluster_score:
                max_cluster_score = score

        scores.append((sentence_idx, score))

    return scores

def summarize(txt):
    sentences = [s for s in nltk.tokenize.sent_tokenize(txt)]
    normalized_sentences = [s.lower() for s in sentences]

    words = [w.lower() for sentence in normalized_sentences for w in
             nltk.tokenize.word_tokenize(sentence)]

    fdist = nltk.FreqDist(words)

    top_n_words = [w[0] for w in fdist.items() 
            if w[0] not in nltk.corpus.stopwords.words('portuguese')][:N]

    scored_sentences = _score_sentences(normalized_sentences, top_n_words)

    # Summaization Approach 1:
    # Filter out non-significant sentences by using the average score plus a
    # fraction of the std dev as a filter

    avg = numpy.mean([s[1] for s in scored_sentences])
    std = numpy.std([s[1] for s in scored_sentences])
    mean_scored = [(sent_idx, score) for (sent_idx, score) in scored_sentences
                   if score > avg + 0.5 * std]

    # Summarization Approach 2:
    # Another approach would be to return only the top N ranked sentences

    top_n_scored = sorted(scored_sentences, key=lambda s: s[1])[-TOP_SENTENCES:]
    top_n_scored = sorted(top_n_scored, key=lambda s: s[0])

    # Decorate the post object with summaries

    return dict(top_n_summary=[sentences[idx] for (idx, score) in top_n_scored],
                mean_scored_summary=[sentences[idx] for (idx, score) in mean_scored])


if __name__ == '__main__':

    # Load in output from blogs_and_nlp__get_feed.py

    #BLOG_DATA = sys.argv[1]
    #blog_data = json.loads(open(BLOG_DATA).read())
    
    for post in news_data:
       
        post.update(summarize(post['content']))

        print(post['title'])
        print('-' * len(post['title']))
        print()
        print('-------------')
        print('Top N Summary')
        print('-------------')
        print(' '.join(post['top_n_summary']))
        print()
        print('-------------------')
        print('Mean Scored Summary')
        print('-------------------')
        print(' '.join(post['mean_scored_summary']))
        print()
# Out:
# Entidade pede que Ministério Público do RS analise fala do vice de Bolsonaro sobre negros
# ------------------------------------------------------------------------------------------
#
# -------------
# Top N Summary
# -------------
#
#  A entidade Educafro protocolou no Ministério Público do Rio Grande do Sul (MP-RS) nesta sexta-feira (10) uma solicitação para que o órgão analise a declaração do general Antonio Hamilton Mourão (PRTB), candidato a vice-presidente na chapa de Jair Bolsonaro (PSL) nas Eleições de 2018, que disse que o Brasil herdou a "malandragem" do africano. O político estava em uma reunião-almoço da Câmara de Indústria, Comércio e Serviços de Caxias do Sul, na Serra do Rio Grande do Sul, na segunda-feira (6), quando deu a declaração. No documento encaminhado ao MP, dois dos advogados da Educafro, Ary Bergher e Marcello Ramalho, citam que "ao vociferar a qualidade negativa do negro na composição cultural do Povo Brasileiro, traz à tona uma aversão aos seus valores e culturas, manifestando, em tese, um racismo não apoiado em bases biológicas, mas sim, numa incompatibilidade entre estes valores e os que sustentam a chamada 'Civilização Ocidental' ao qual o Brasil está incutido". Na terça-feira (7), entidades repudiaram a fala do vice de Bolsonaro. Também durante o evento, ele havia dito que o Brasil herdou "indolência" do índio.
#
# -------------------
# Mean Scored Summary
# -------------------
#
#  A entidade Educafro protocolou no Ministério Público do Rio Grande do Sul (MP-RS) nesta sexta-feira (10) uma solicitação para que o órgão analise a declaração do general Antonio Hamilton Mourão (PRTB), candidato a vice-presidente na chapa de Jair Bolsonaro (PSL) nas Eleições de 2018, que disse que o Brasil herdou a "malandragem" do africano.
#
# Após debate morno, estrategistas de Alckmin defendem confrontar Bolsonaro na campanha da TV
# -------------------------------------------------------------------------------------------
#
# -------------
# Top N Summary
# -------------
#
#  O primeiro debate presidencial na TV dividiu opiniões entre as campanhas dos principais candidatos, mas servirá de "termômetro" para "calibrar" a estratégia no horário eleitoral de Geraldo Alckmin, por exemplo. Aliados de Alckmin admitem que foi calculada a estratégia do tucano de evitar o confronto direto com Jair Bolsonaro, considerado o principal adversário nesta primeira fase. De preferência, afirmam, nas peças em que Alckmin não apareça – os chamados "spots" (rápidas inserções de propaganda televisiva). Isso seria especialmente negativo no momento em que o PSDB está desgastado devido às denúncias de corrupção envolvendo seus principais líderes. Avaliam, inclusive, que o candidato do Patriota, Cabo Daciolo, lembrou, na sintonia com Bolsonaro, a dobradinha que Aécio Neves (PSDB) fez com Pastor Everaldo (PSC) em 2014.
#
# -------------------
# Mean Scored Summary
# -------------------
#
#  O primeiro debate presidencial na TV dividiu opiniões entre as campanhas dos principais candidatos, mas servirá de "termômetro" para "calibrar" a estratégia no horário eleitoral de Geraldo Alckmin, por exemplo. Aliados de Alckmin admitem que foi calculada a estratégia do tucano de evitar o confronto direto com Jair Bolsonaro, considerado o principal adversário nesta primeira fase. De preferência, afirmam, nas peças em que Alckmin não apareça – os chamados "spots" (rápidas inserções de propaganda televisiva). Avaliam, inclusive, que o candidato do Patriota, Cabo Daciolo, lembrou, na sintonia com Bolsonaro, a dobradinha que Aécio Neves (PSDB) fez com Pastor Everaldo (PSC) em 2014.

# %% [markdown]
# ### Visualização HTML da sumarização

# %%
import os
import sys
import json
import nltk
import numpy

HTML_TEMPLATE = """<html>
    <head>
        <title>%s</title>
        <meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/>
    </head>
    <body>%s</body>
</html>"""

if __name__ == '__main__':

    # Marked up version can be written out to disk

    if not os.path.isdir('out/summarize'):
        os.makedirs('out/summarize')

    for post in news_data:
       
        post.update(summarize(post['content']))

        for summary_type in ['top_n_summary', 'mean_scored_summary']:
            post[summary_type + '_marked_up'] = '<p>%s</p>' % (post['content'], )
            for s in post[summary_type]:
                post[summary_type + '_marked_up'] = \
                post[summary_type + '_marked_up'].replace(s, '<strong>%s</strong>' % (s, ))

            filename = post['title'] + '.summary.' + summary_type + '.html'
            f = open(os.path.join('out', 'summarize', filename), 'w')
            html = HTML_TEMPLATE % (post['title'] + ' Summary', post[summary_type + '_marked_up'],)
            #f.write(str(html.encode('utf-8')))
            f.write(html)
            f.close()

            print("Data written to", f.name)
# Out:
# Data written to out\summarize\Entidade pede que Ministério Público do RS analise fala do vice de Bolsonaro sobre negros .summary.top_n_summary.html
# Data written to out\summarize\Entidade pede que Ministério Público do RS analise fala do vice de Bolsonaro sobre negros .summary.mean_scored_summary.html
# Data written to out\summarize\Após debate morno, estrategistas de Alckmin defendem confrontar Bolsonaro na campanha da TV.summary.top_n_summary.html
# Data written to out\summarize\Após debate morno, estrategistas de Alckmin defendem confrontar Bolsonaro na campanha da TV.summary.mean_scored_summary.html
