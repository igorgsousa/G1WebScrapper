# %% [markdown]
# ### Coletando notícias do G1

# %%
import time
from selenium import webdriver
import csv

# %%
import requests
from bs4 import BeautifulSoup

class G1PageScrapper:
    
    mainUrl = "https://g1.globo.com/"
    searchPath = "busca/?q="
    
    
    def __init__(self):
        self.data = []
    
    def access(self, link):
        ret = BeautifulSoup(requests.get(link).content, 'html.parser')
        return ret
        
    def search(self, expression, page=1):
        words = expression.split(" ")
        
        queryParamValue =  ""
        
        for word in words:
            queryParamValue += '+' + word 
        
        queryParamValue = queryParamValue.replace('+','',1)    
        
        searchUrl = self.mainUrl+self.searchPath+queryParamValue
               
        return G1SearchReader(self.access(searchUrl))
    
class G1SearchReader:
    
    def __init__(self, bsObject):
        self.content = bsObject
    
    def getContent(self):
        return self.content
    
    def listNewsCardList(self):
        cardsList = self.content.find_all(class_="widget widget--card widget--info") 
        
        ret = []
        
        for card in cardsList:
            ret.append(G1NewsCard(card))
        
        return 
    
class G1NewsCard:
    
    def __init__(self, bsObject):
        self.content = bsObject
        self.
        
    
    def getContent(self):
        return self.content

# %%
links = ['https://g1.globo.com/rs/rio-grande-do-sul/noticia/2018/08/10/entidade-pede-que-ministerio-publico-do-rs-analise-fala-do-vice-de-bolsonaro-sobre-negros.ghtml',
        'https://g1.globo.com/politica/blog/andreia-sadi/post/2018/08/10/apos-debate-morno-estrategistas-de-alckmin-defendem-campanha-na-tv-para-confrontar-bolsonaro.ghtml'
        ]

webPageScrapper = G1PageScrapper()

searchReader = webPageScrapper.search("jair bolsonaro")

searchReader.listNewsCardList()
print()
# Out:
# [<li class="widget widget--card widget--info" data-position="1">
# <div class="widget--info__meta--card">
# <span>G1 Eleições 2018</span>
# <span>•</span>
# <span>há 2 dias</span>
# </div>
# <div class="widget--info__media-container ">
# <a class="widget--info__media widget--info__media--video" href="//g1.globo.com/busca/click?abTestId=cf859a93-6ff3-4662-be42-675d001c3fa9&amp;abAlternative=Default&amp;q=jair+bolsonaro&amp;p=1&amp;r=1534829100501&amp;u=http%3A%2F%2Fg1.globo.com%2Fvideos%2Fv%2Fjair-bolsonaro-em-cerimonia-de-entrega-de-espadins-na-academia-militar-das-agulhas-negras%2F6954957%2F&amp;abExperiment=bg-g1-decaimento-quadrado&amp;key=73ba0d76474654795865cf6f6ba94391">
# <img src="//s02.video.glbimg.com/x216/6954957.jpg">
# <div class="widget--info__media-time">00:15</div>
# </img></a>
# </div>
# <div class="widget--info__text-container">
# <div class="widget--info__header">G1 Eleições 2018</div>
# <a href="//g1.globo.com/busca/click?abTestId=cf859a93-6ff3-4662-be42-675d001c3fa9&amp;abAlternative=Default&amp;q=jair+bolsonaro&amp;p=1&amp;r=1534829100502&amp;u=http%3A%2F%2Fg1.globo.com%2Fvideos%2Fv%2Fjair-bolsonaro-em-cerimonia-de-entrega-de-espadins-na-academia-militar-das-agulhas-negras%2F6954957%2F&amp;abExperiment=bg-g1-decaimento-quadrado&amp;key=af28163098e4ddb09dc335532a0ed9fa">
# <div class="widget--info__title product-color ">
#         Jair Bolsonaro em cerimônia de entrega de espadins na Academia Militar das Agulhas Negras
#       </div>
# <p class="widget--info__description"><span><em>Jair</em> <em>Bolsonaro</em> participou de cerimônia de entrega de espadins na Academia Militar das Agulhas Negras, em Resende, no Sul do Rio de Janeiro.</span></p>
# <div class="widget--info__meta">há 2 dias</div>
# </a>
# </div>
# </li>, <li class="widget widget--card widget--info" data-position="2">
# <div class="widget--info__meta--card">
# <span>G1 Eleições 2018</span>
# <span>•</span>
# <span>há 3 dias</span>
# </div>
# <div class="widget--info__media-container ">
# <a class="widget--info__media widget--info__media--video" href="//g1.globo.com/busca/click?abTestId=cf859a93-6ff3-4662-be42-675d001c3fa9&amp;abAlternative=Default&amp;q=jair+bolsonaro&amp;p=2&amp;r=1534829100505&amp;u=http%3A%2F%2Fg1.globo.com%2Fvideos%2Fv%2Fo-candidato-do-psl-a-presidencia-da-republica-jair-bolsonaro-durante-cerimonia-em-sp%2F6952008%2F&amp;abExperiment=bg-g1-decaimento-quadrado&amp;key=ae303aa7c10f573000b84c9690eccdfe">
# <img src="//s01.video.glbimg.com/x216/6952008.jpg">
# <div class="widget--info__media-time">00:12</div>
# </img></a>
# </div>
# <div class="widget--info__text-container">
# <div class="widget--info__header">G1 Eleições 2018</div>
# <a href="//g1.globo.com/busca/click?abTestId=cf859a93-6ff3-4662-be42-675d001c3fa9&amp;abAlternative=Default&amp;q=jair+bolsonaro&amp;p=2&amp;r=1534829100506&amp;u=http%3A%2F%2Fg1.globo.com%2Fvideos%2Fv%2Fo-candidato-do-psl-a-presidencia-da-republica-jair-bolsonaro-durante-cerimonia-em-sp%2F6952008%2F&amp;abExperiment=bg-g1-decaimento-quadrado&amp;key=39f158af0b39470e746875847134a120">
# <div class="widget--info__title product-color ">
#         O candidato do PSL à Presidência da República, Jair Bolsonaro, durante cerimônia em SP
#       </div>
# <p class="widget--info__description"><span>O candidato do PSL à Presidência da República, <em>Jair</em> <em>Bolsonaro</em>, participa de cerimônia de formatura de sargentos da Polícia Militar de São Paulo.</span></p>
# <div class="widget--info__meta">há 3 dias</div>
# </a>
# </div>
# </li>, <li class="widget widget--card widget--info" data-position="3">
# <div class="widget--info__meta--card">
# <span>G1</span>
# <span>•</span>
# <span>há 3 dias</span>
# </div>
# <div class="widget--info__text-container">
# <div class="widget--info__header">G1</div>
# <a href="//g1.globo.com/busca/click?abTestId=cf859a93-6ff3-4662-be42-675d001c3fa9&amp;abAlternative=Default&amp;q=jair+bolsonaro&amp;p=3&amp;r=1534829100508&amp;u=https%3A%2F%2Fg1.globo.com%2Fsp%2Fsao-paulo%2Feleicoes%2F2018%2Fnoticia%2Fem-sp-ibope-aponta-para-presidente-lula-23-jair-bolsonaro-19-geraldo-alckmin-13.ghtml&amp;abExperiment=bg-g1-decaimento-quadrado&amp;key=c5ca72408b9ae723da8f2448507679d4">
# <div class="widget--info__title product-color ">
#         Em SP, Ibope aponta para presidente: Lula, 23%; Jair Bolsonaro, 19%; Geraldo Alckmin, 13%
#       </div>
# <p class="widget--info__description"><span>...%
# <em>Jair</em> <em>Bolsonaro</em> (PSL): 19%
# Geraldo Alckmin (PSDB): 13%
# Marina Silva (Rede): 9%
# Ciro Gomes (PDT): 3%
# Álvaro Dias (Podemos): 2...</span> — <span>...%
# Paulo Rabelo de Castro (PSC): 0%
# Branco/nulo: 21%
# Não sabe/não respondeu: 5%
# 2º cenário
# <em>Jair</em> <em>Bolsonaro</em> (PSL): 19%
# Geraldo Alckmin...</span></p>
# <div class="widget--info__meta">há 3 dias</div>
# </a>
# </div>
# </li>, <li class="widget widget--card widget--info" data-position="4">
# <div class="widget--info__meta--card">
# <span>G1 Eleições 2018</span>
# <span>•</span>
# <span>há 3 dias</span>
# </div>
# <div class="widget--info__media-container ">
# <a class="widget--info__media widget--info__media--video" href="//g1.globo.com/busca/click?abTestId=cf859a93-6ff3-4662-be42-675d001c3fa9&amp;abAlternative=Default&amp;q=jair+bolsonaro&amp;p=4&amp;r=1534829100510&amp;u=http%3A%2F%2Fg1.globo.com%2Fvideos%2Fv%2Fo-candidato-do-psl-a-presidencia-da-republica-jair-bolsonaro-posou-para-fotografias-em-sp%2F6952040%2F&amp;abExperiment=bg-g1-decaimento-quadrado&amp;key=5c72394540ca8ffb1242095fef4bc9be">
# <img src="//s01.video.glbimg.com/x216/6952040.jpg">
# <div class="widget--info__media-time">00:36</div>
# </img></a>
# </div>
# <div class="widget--info__text-container">
# <div class="widget--info__header">G1 Eleições 2018</div>
# <a href="//g1.globo.com/busca/click?abTestId=cf859a93-6ff3-4662-be42-675d001c3fa9&amp;abAlternative=Default&amp;q=jair+bolsonaro&amp;p=4&amp;r=1534829100511&amp;u=http%3A%2F%2Fg1.globo.com%2Fvideos%2Fv%2Fo-candidato-do-psl-a-presidencia-da-republica-jair-bolsonaro-posou-para-fotografias-em-sp%2F6952040%2F&amp;abExperiment=bg-g1-decaimento-quadrado&amp;key=5001a31a77a9ffc1e6c792e0c97870ca">
# <div class="widget--info__title product-color ">
#         O candidato do PSL à Presidência da República Jair Bolsonaro posou para fotografias em SP
#       </div>
# <p class="widget--info__description"><span><em>Bolsonaro</em> caminha ao lado de correligionários depois de cerimônia de formatura de sargentos da Polícia Militar de São Paulo.</span></p>
# <div class="widget--info__meta">há 3 dias</div>
# </a>
# </div>
# </li>, <li class="widget widget--card widget--info" data-position="5">
# <div class="widget--info__meta--card">
# <span>Hora 1</span>
# <span>•</span>
# <span>há 6 dias</span>
# </div>
# <div class="widget--info__media-container ">
# <a class="widget--info__media widget--info__media--video" href="//g1.globo.com/busca/click?abTestId=cf859a93-6ff3-4662-be42-675d001c3fa9&amp;abAlternative=Default&amp;q=jair+bolsonaro&amp;p=5&amp;r=1534829100514&amp;u=https%3A%2F%2Fgloboplay.globo.com%2Fv%2F6943072%2F&amp;abExperiment=bg-g1-decaimento-quadrado&amp;key=6c7246d1c7c166bf95c63ce7804e6ba1">
# <img src="//s01.video.glbimg.com/x216/6943072.jpg">
# <div class="widget--info__media-time">01:38</div>
# </img></a>
# </div>
# <div class="widget--info__text-container">
# <div class="widget--info__header">Hora 1</div>
# <a href="//g1.globo.com/busca/click?abTestId=cf859a93-6ff3-4662-be42-675d001c3fa9&amp;abAlternative=Default&amp;q=jair+bolsonaro&amp;p=5&amp;r=1534829100515&amp;u=https%3A%2F%2Fgloboplay.globo.com%2Fv%2F6943072%2F&amp;abExperiment=bg-g1-decaimento-quadrado&amp;key
2F&amp;abExperiment=bg-g1-decaimento-quadrado&amp;key=e768b10216d378cbdc50c3c5f5103a66">
# <div class="widget--info__title product-color ">
#         Fato ou Fake analisa entrevista do candidato à presidência Jair Bolsonaro (PSL)
#       </div>
# <p class="widget--info__description">O candidato pelo PSL falou, em entrevista à GloboNews, sobre a presidência de Donald Trump e a operação Lava Jato.</p>
# <div class="widget--info__meta">07/08/2018 01h09</div>
# </a>
# </div>
# </li>, <li class="widget widget--card widget--info" data-position="11">
# <div class="widget--info__meta--card">
# <span>Jornal Hoje</span>
# <span>•</span>
# <span>06/08/2018 15h43</span>
# </div>
# <div class="widget--info__media-container ">
# <a class="widget--info__media widget--info__media--video" href="//g1.globo.com/busca/click?abTestId=cf859a93-6ff3-4662-be42-675d001c3fa9&amp;abAlternative=Default&amp;q=jair+bolsonaro&amp;p=11&amp;r=1534829100538&amp;u=https%3A%2F%2Fgloboplay.globo.com%2Fv%2F6925595%2F&amp;abExperiment=bg-g1-decaimento-quadrado&amp;key=0ca4827c7a28afa75f7cd3409f366077">
# <img src="//s04.video.glbimg.com/x216/6925595.jpg"/>
# <div class="widget--info__media-time">00:14</div>
# </a>
# </div>
# <div class="widget--info__text-container">
# <div class="widget--info__header">Jornal Hoje</div>
# <a href="//g1.globo.com/busca/click?abTestId=cf859a93-6ff3-4662-be42-675d001c3fa9&amp;abAlternative=Default&amp;q=jair+bolsonaro&amp;p=11&amp;r=1534829100539&amp;u=https%3A%2F%2Fgloboplay.globo.com%2Fv%2F6925595%2F&amp;abExperiment=bg-g1-decaimento-quadrado&amp;key=916acd419c4dff932b5509c9fbc64ded">
# <div class="widget--info__title product-color ">
#         PRTB anuncia apoio a Jair Bolsonaro, candidato do PSL à presidência
#       </div>
# <p class="widget--info__description"><span>O PRTB também indicou o general da reserva Hamilton Mourão como vice, na chapa de <em>Bolsonaro</em>.</span></p>
# <div class="widget--info__meta">06/08/2018 15h43</div>
# </a>
# </div>
# </li>, <li class="widget widget--card widget--info" data-position="12">
# <div class="widget--info__meta--card">
# <span>Hora 1</span>
# <span>•</span>
# <span>06/08/2018 06h12</span>
# </div>
# <div class="widget--info__media-container ">
# <a class="widget--info__media widget--info__media--video" href="//g1.globo.com/busca/click?abTestId=cf859a93-6ff3-4662-be42-675d001c3fa9&amp;abAlternative=Default&amp;q=jair+bolsonaro&amp;p=12&amp;r=1534829100542&amp;u=https%3A%2F%2Fgloboplay.globo.com%2Fv%2F6923840%2F&amp;abExperiment=bg-g1-decaimento-quadrado&amp;key=98bdc342b90dc8f0ab0aebfdaf323ac1">
# <img src="//s01.video.glbimg.com/x216/6923840.jpg"/>
# <div class="widget--info__media-time">00:40</div>
# </a>
# </div>
# <div class="widget--info__text-container">
# <div class="widget--info__header">Hora 1</div>
# <a href="//g1.globo.com/busca/click?abTestId=cf859a93-6ff3-4662-be42-675d001c3fa9&amp;abAlternative=Default&amp;q=jair+bolsonaro&amp;p=12&amp;r=1534829100543&amp;u=https%3A%2F%2Fgloboplay.globo.com%2Fv%2F6923840%2F&amp;abExperiment=bg-g1-decaimento-quadrado&amp;key=a4e15fd911c374924141017a269b1266">
# <div class="widget--info__title product-color ">
#         PRTB decide apoiar candidatura de Jair Bolsonaro à presidência da República
#       </div>
# <p class="widget--info__description"><span>Na convenção nacional, o partido também indicou o general da reserva Hamilton Mourão como vice, nome já confirmado por <em>Bolsonaro</em>.</span></p>
# <div class="widget--info__meta">06/08/2018 06h12</div>
# </a>
# </div>
# </li>, <li class="widget widget--card widget--info" data-position="13">
# <div class="widget--info__meta--card">
# <span>G1</span>
# <span>•</span>
# <span>04/08/2018 13h48</span>
# </div>
# <div class="widget--info__text-container">
# <div class="widget--info__header">G1</div>
# <a href="//g1.globo.com/busca/click?abTestId=cf859a93-6ff3-4662-be42-675d001c3fa9&amp;abAlternative=Default&amp;q=jair+bolsonaro&amp;p=13&amp;r=1534829100545&amp;u=https%3A%2F%2Fg1.globo.com%2Fpolitica%2Feleicoes%2F2018%2Fnoticia%2F2018%2F08%2F04%2Fem-sp-ibope-aponta-para-presidente-lula-23-jair-bolsonaro-18-geraldo-alckmin-15.ghtml&amp;abExperiment=bg-g1-decaimento-quadrado&amp;key=01ecb21209baa7f97cbb8d77188b9796">
# <div class="widget--info__title product-color ">
#         Em SP, Ibope aponta para presidente: Lula, 23%; Jair Bolsonaro, 18%; Geraldo Alckmin, 15%
#       </div>
# <p class="widget--info__description"><span>.../não respondeu: 6%
# Cenário 2
# Geraldo Alckmin (PSDB): 19%
# <em>Jair</em> <em>Bolsonaro</em> (PSL): 16%
# Marina Silva (Rede): 11%
# Ciro Gomes (PDT): 8%
# Alvaro Dias...</span> — <span>... (PSC): 0%
# Branco/nulo: 23%
# Não sabe/não respondeu: 7%
# Rejeição de voto para presidente
# Lula (PT): 44%
# <em>Jair</em> <em>Bolsonaro</em> (PSL): 30...</span></p>
# <div class="widget--info__meta">04/08/2018 13h48</div>
# </a>
# </div>
# </li>, <li class="widget widget--card widget--info" data-position="14">
# <div class="widget--info__meta--card">
# <span>G1</span>
# <span>•</span>
# <span>04/08/2018 05h22</span>
# </div>
# <div class="widget--info__media-container ">
# <a class="widget--info__media widget--info__media--video" href="//g1.globo.com/busca/click?abTestId=cf859a93-6ff3-4662-be42-675d001c3fa9&amp;abAlternative=Default&amp;q=jair+bolsonaro&amp;p=14&amp;r=1534829100549&amp;u=https%3A%2F%2Fg1.globo.com%2Fpolitica%2Feleicoes%2F2018%2Fnoticia%2F2018%2F08%2F04%2Fjair-bolsonaro-diz-que-se-eleito-pode-privatizar-petrobras-se-nao-tiver-solucao.ghtml&amp;abExperiment=bg-g1-decaimento-quadrado&amp;key=f47eea92cc8ee208de4ac0e232f9333c">
# <img src="//s2.glbimg.com/TqvmwZI-MFLMQrRfD-VugMLUAMA=/346x195/smart/http%3A//s.glbimg.com/jo/g1/f/original/2018/08/03/frame_00_21_49.455_1.jpg"/>
# </a>
# </div>
# <div class="widget--info__text-container">
# <div class="widget--info__header">G1</div>
# <a href="//g1.globo.com/busca/click?abTestId=cf859a93-6ff3-4662-be42-675d001c3fa9&amp;abAlternative=Default&amp;q=jair+bolsonaro&amp;p=14&amp;r=1534829100550&amp;u=https%3A%2F%2Fg1.globo.com%2Fpolitica%2Feleicoes%2F2018%2Fnoticia%2F2018%2F08%2F04%2Fjair-bolsonaro-diz-que-se-eleito-pode-privatizar-petrobras-se-nao-tiver-solucao.ghtml&amp;abExperiment=bg-g1-decaimento-quadrado&amp;key=7bcc490489357c016b7d5f9f0cbff642">
# <div class="widget--info__title product-color ">
#         Jair Bolsonaro diz que, se eleito, pode privatizar Petrobras 'se não tiver solução'
#       </div>
# <p class="widget--info__description"><span>O candidato do PSL à Presidência, <em>Jair</em> <em>Bolsonaro</em>, durante entrevista à GloboNews
# Reprodução/GloboNews
# O candidato do PSL...</span> — <span>... à Presidência da República, <em>Jair</em> <em>Bolsonaro</em>, afirmou nesta sexta-feira (3) que, se eleito, pode privatizar a Petrobras "se não tiver...</span></p>
# <div class="widget--info__meta">04/08/2018 05h22</div>
# </a>
# </div>
# </li>, <li class="widget widget--card widget--info" data-position="15">
# <div class="widget--info__meta--card">
# <span>Jornal Nacional</span>
# <span>•</span>
# <span>04/08/2018 21h02</span>
# </div>
# <div class="widget--info__media-container ">
# <a class="widget--info__media widget--info__media--video" href="//g1.globo.com/busca/click?abTestId=cf859a93-6ff3-4662-be42-675d001c3fa9&amp;abAlternative=Default&amp;q=jair+bolsonaro&amp;p=15&amp;r=1534829100553&amp;u=https%3A%2F%2Fgloboplay.globo.com%2Fv%2F6923157%2F&amp;abExperiment=bg-g1-decaimento-quadrado&amp;key=df1630defd724f4055ca8d8b818b88df">
# <img src="//s02.video.glbimg.com/x216/6923157.jpg"/>
# <div class="widget--info__media-time">00:55</div>
# </a>
# </div>
# <div class="widget--info__text-container">
# <div class="widget--info__header">Jornal Nacional</div>
# <a href="//g1.globo.com/busca/click?abTestId=cf859a93-6ff3-4662-be42-675d001c3fa9&amp;abAlternative=Default&amp;q=jair+bolsonaro&amp;p=15&amp;r=1534829100554&amp;u=https%3A%2F%2Fgloboplay.globo.com%2Fv%2F6923157%2F&amp;abExperiment=bg-g1-decaimento-quadrado&amp;key=eec99bdec50f5e69d29d189d7ab6057b">
# <div class="widget--info__title product-color ">
#         Janaína Paschoal nega convite para ser vice na chapa de Jair Bolsonaro
#       </div>
# <p class="widget--info__description">A advogada, coautora do pedido do impeachment da presidente Dilma Roussef, usou a internet para anunciar a decisão.</p>
# <div class="widget--info__meta">04/08/2018 21h02</div>
# </a>
# </div>
# </li>]

# %%
news_data = []
for link in links:
    title, texto = webPageScrapper.access(link)
    news_data.append({'title': title, 'content': texto})

for news in news_data:
    print(news['title'], '\n\n', news['content'], '\n\n\n')

# %% [markdown]
# ### Calculando estatísticas básicas de cada notícia coletada (news_data)

# %%
import sys
import json
import nltk



stop_words = nltk.corpus.stopwords.words('portuguese') + [
    '.',
    ',',
    '--',
    '\'s',
    '?',
    ')',
    '(',
    ':',
    '\'',
    '\'re',
    '"',
    '-',
    '}',
    '{',
    ]

for news in news_data:
    sentences = nltk.tokenize.sent_tokenize(news['content'])

    words = [w.lower() for sentence in sentences for w in
             nltk.tokenize.word_tokenize(sentence)]

    fdist = nltk.FreqDist(words)

    # Basic stats

    num_words = sum([i[1] for i in fdist.items()])
    num_unique_words = len(fdist.keys())

    # Hapaxes are words that appear only once

    num_hapaxes = len(fdist.hapaxes())

    top_10_words_sans_stop_words = [w for w in fdist.items() if w[0]
                                    not in stop_words][:10]

    print(news['title'])
    print('\tNum Sentences:'.ljust(25), len(sentences))
    print('\tNum Words:'.ljust(25), num_words)
    print('\tNum Unique Words:'.ljust(25), num_unique_words)
    print('\tNum Hapaxes:'.ljust(25), num_hapaxes)
    print('\tTop 10 Most Frequent Words (sans stop words):\n\t\t', \
            '\n\t\t'.join(['%s (%s)'
            % (w[0], w[1]) for w in top_10_words_sans_stop_words]))
    print()
# Out:
# Entidade pede que Ministério Público do RS analise fala do vice de Bolsonaro sobre negros
# 	Num Sentences:           10
# 	Num Words:               400
# 	Num Unique Words:        216
# 	Num Hapaxes:             167
# 	Top 10 Most Frequent Words (sans stop words):
# 		 entidade (1)
# 		educafro (3)
# 		protocolou (1)
# 		ministério (1)
# 		público (1)
# 		rio (2)
# 		grande (2)
# 		sul (3)
# 		mp-rs (1)
# 		nesta (1)
#
# Após debate morno, estrategistas de Alckmin defendem confrontar Bolsonaro na campanha da TV
# 	Num Sentences:           20
# 	Num Words:               410
# 	Num Unique Words:        199
# 	Num Hapaxes:             142
# 	Top 10 Most Frequent Words (sans stop words):
# 		 primeiro (1)
# 		debate (3)
# 		presidencial (1)
# 		tv (3)
# 		dividiu (1)
# 		opiniões (1)
# 		campanhas (2)
# 		principais (4)
# 		candidatos (1)
# 		servirá (1)

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Igor\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %% [markdown]
# ### Sumarizando as notícias coletadas

# %%
import sys
import json
import nltk
import numpy

N = 100  # Number of words to consider
CLUSTER_THRESHOLD = 5  # Distance between words to consider
TOP_SENTENCES = 5  # Number of sentences to return for a "top n" summary

# Approach taken from "The Automatic Creation of Literature Abstracts" by H.P. Luhn

def _score_sentences(sentences, important_words):
    scores = []
    sentence_idx = -1

    for s in [nltk.tokenize.word_tokenize(s) for s in sentences]:

        sentence_idx += 1
        word_idx = []

        # For each word in the word list...
        for w in important_words:
            try:
                # Compute an index for where any important words occur in the sentence

                word_idx.append(s.index(w))
            except (ValueError) as e: # w not in this particular sentence
                pass

        word_idx.sort()

        # It is possible that some sentences may not contain any important words at all
        if len(word_idx)== 0: continue

        # Using the word index, compute clusters by using a max distance threshold
        # for any two consecutive words

        clusters = []
        cluster = [word_idx[0]]
        i = 1
        while i < len(word_idx):
            if word_idx[i] - word_idx[i - 1] < CLUSTER_THRESHOLD:
                cluster.append(word_idx[i])
            else:
                clusters.append(cluster[:])
                cluster = [word_idx[i]]
            i += 1
        clusters.append(cluster)

        # Score each cluster. The max score for any given cluster is the score 
        # for the sentence

        max_cluster_score = 0
        for c in clusters:
            significant_words_in_cluster = len(c)
            total_words_in_cluster = c[-1] - c[0] + 1
            score = 1.0 * significant_words_in_cluster \
                * significant_words_in_cluster / total_words_in_cluster

            if score > max_cluster_score:
                max_cluster_score = score

        scores.append((sentence_idx, score))

    return scores

def summarize(txt):
    sentences = [s for s in nltk.tokenize.sent_tokenize(txt)]
    normalized_sentences = [s.lower() for s in sentences]

    words = [w.lower() for sentence in normalized_sentences for w in
             nltk.tokenize.word_tokenize(sentence)]

    fdist = nltk.FreqDist(words)

    top_n_words = [w[0] for w in fdist.items() 
            if w[0] not in nltk.corpus.stopwords.words('portuguese')][:N]

    scored_sentences = _score_sentences(normalized_sentences, top_n_words)

    # Summaization Approach 1:
    # Filter out non-significant sentences by using the average score plus a
    # fraction of the std dev as a filter

    avg = numpy.mean([s[1] for s in scored_sentences])
    std = numpy.std([s[1] for s in scored_sentences])
    mean_scored = [(sent_idx, score) for (sent_idx, score) in scored_sentences
                   if score > avg + 0.5 * std]

    # Summarization Approach 2:
    # Another approach would be to return only the top N ranked sentences

    top_n_scored = sorted(scored_sentences, key=lambda s: s[1])[-TOP_SENTENCES:]
    top_n_scored = sorted(top_n_scored, key=lambda s: s[0])

    # Decorate the post object with summaries

    return dict(top_n_summary=[sentences[idx] for (idx, score) in top_n_scored],
                mean_scored_summary=[sentences[idx] for (idx, score) in mean_scored])


if __name__ == '__main__':

    # Load in output from blogs_and_nlp__get_feed.py

    #BLOG_DATA = sys.argv[1]
    #blog_data = json.loads(open(BLOG_DATA).read())
    
    for post in news_data:
       
        post.update(summarize(post['content']))

        print(post['title'])
        print('-' * len(post['title']))
        print()
        print('-------------')
        print('Top N Summary')
        print('-------------')
        print(' '.join(post['top_n_summary']))
        print()
        print('-------------------')
        print('Mean Scored Summary')
        print('-------------------')
        print(' '.join(post['mean_scored_summary']))
        print()
# Out:
# Entidade pede que Ministério Público do RS analise fala do vice de Bolsonaro sobre negros
# ------------------------------------------------------------------------------------------
#
# -------------
# Top N Summary
# -------------
#
#  A entidade Educafro protocolou no Ministério Público do Rio Grande do Sul (MP-RS) nesta sexta-feira (10) uma solicitação para que o órgão analise a declaração do general Antonio Hamilton Mourão (PRTB), candidato a vice-presidente na chapa de Jair Bolsonaro (PSL) nas Eleições de 2018, que disse que o Brasil herdou a "malandragem" do africano. O político estava em uma reunião-almoço da Câmara de Indústria, Comércio e Serviços de Caxias do Sul, na Serra do Rio Grande do Sul, na segunda-feira (6), quando deu a declaração. No documento encaminhado ao MP, dois dos advogados da Educafro, Ary Bergher e Marcello Ramalho, citam que "ao vociferar a qualidade negativa do negro na composição cultural do Povo Brasileiro, traz à tona uma aversão aos seus valores e culturas, manifestando, em tese, um racismo não apoiado em bases biológicas, mas sim, numa incompatibilidade entre estes valores e os que sustentam a chamada 'Civilização Ocidental' ao qual o Brasil está incutido". Na terça-feira (7), entidades repudiaram a fala do vice de Bolsonaro. Também durante o evento, ele havia dito que o Brasil herdou "indolência" do índio.
#
# -------------------
# Mean Scored Summary
# -------------------
#
#  A entidade Educafro protocolou no Ministério Público do Rio Grande do Sul (MP-RS) nesta sexta-feira (10) uma solicitação para que o órgão analise a declaração do general Antonio Hamilton Mourão (PRTB), candidato a vice-presidente na chapa de Jair Bolsonaro (PSL) nas Eleições de 2018, que disse que o Brasil herdou a "malandragem" do africano.
#
# Após debate morno, estrategistas de Alckmin defendem confrontar Bolsonaro na campanha da TV
# -------------------------------------------------------------------------------------------
#
# -------------
# Top N Summary
# -------------
#
#  O primeiro debate presidencial na TV dividiu opiniões entre as campanhas dos principais candidatos, mas servirá de "termômetro" para "calibrar" a estratégia no horário eleitoral de Geraldo Alckmin, por exemplo. Aliados de Alckmin admitem que foi calculada a estratégia do tucano de evitar o confronto direto com Jair Bolsonaro, considerado o principal adversário nesta primeira fase. De preferência, afirmam, nas peças em que Alckmin não apareça – os chamados "spots" (rápidas inserções de propaganda televisiva). Isso seria especialmente negativo no momento em que o PSDB está desgastado devido às denúncias de corrupção envolvendo seus principais líderes. Avaliam, inclusive, que o candidato do Patriota, Cabo Daciolo, lembrou, na sintonia com Bolsonaro, a dobradinha que Aécio Neves (PSDB) fez com Pastor Everaldo (PSC) em 2014.
#
# -------------------
# Mean Scored Summary
# -------------------
#
#  O primeiro debate presidencial na TV dividiu opiniões entre as campanhas dos principais candidatos, mas servirá de "termômetro" para "calibrar" a estratégia no horário eleitoral de Geraldo Alckmin, por exemplo. Aliados de Alckmin admitem que foi calculada a estratégia do tucano de evitar o confronto direto com Jair Bolsonaro, considerado o principal adversário nesta primeira fase. De preferência, afirmam, nas peças em que Alckmin não apareça – os chamados "spots" (rápidas inserções de propaganda televisiva). Avaliam, inclusive, que o candidato do Patriota, Cabo Daciolo, lembrou, na sintonia com Bolsonaro, a dobradinha que Aécio Neves (PSDB) fez com Pastor Everaldo (PSC) em 2014.

# %% [markdown]
# ### Visualização HTML da sumarização

# %%
import os
import sys
import json
import nltk
import numpy

HTML_TEMPLATE = """<html>
    <head>
        <title>%s</title>
        <meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/>
    </head>
    <body>%s</body>
</html>"""

if __name__ == '__main__':

    # Marked up version can be written out to disk

    if not os.path.isdir('out/summarize'):
        os.makedirs('out/summarize')

    for post in news_data:
       
        post.update(summarize(post['content']))

        for summary_type in ['top_n_summary', 'mean_scored_summary']:
            post[summary_type + '_marked_up'] = '<p>%s</p>' % (post['content'], )
            for s in post[summary_type]:
                post[summary_type + '_marked_up'] = \
                post[summary_type + '_marked_up'].replace(s, '<strong>%s</strong>' % (s, ))

            filename = post['title'] + '.summary.' + summary_type + '.html'
            f = open(os.path.join('out', 'summarize', filename), 'w')
            html = HTML_TEMPLATE % (post['title'] + ' Summary', post[summary_type + '_marked_up'],)
            #f.write(str(html.encode('utf-8')))
            f.write(html)
            f.close()

            print("Data written to", f.name)
# Out:
# Data written to out\summarize\Entidade pede que Ministério Público do RS analise fala do vice de Bolsonaro sobre negros .summary.top_n_summary.html
# Data written to out\summarize\Entidade pede que Ministério Público do RS analise fala do vice de Bolsonaro sobre negros .summary.mean_scored_summary.html
# Data written to out\summarize\Após debate morno, estrategistas de Alckmin defendem confrontar Bolsonaro na campanha da TV.summary.top_n_summary.html
# Data written to out\summarize\Após debate morno, estrategistas de Alckmin defendem confrontar Bolsonaro na campanha da TV.summary.mean_scored_summary.html
